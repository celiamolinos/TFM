# %%
import warnings 
warnings.filterwarnings('ignore')
from datetime import datetime, timedelta

# %% [markdown]
# ### Datos FLU

# %%
import pandas as pd
data=pd.read_csv("./FLU WHO/VIW_FNT.csv", sep=",")
datESP=data[(data.COUNTRY_AREA_TERRITORY=='Spain') & (data.ISO_YEAR>=2008)& (data.ORIGIN_SOURCE=='SENTINEL')]
datESP['Fecha'] = pd.to_datetime(datESP['ISO_WEEKSTARTDATE']) - timedelta(days=1)
flu_ESP=datESP.iloc[:,[4,24,31,32,53]]
flu_ESP.set_index('Fecha', inplace=True)
flu_ESP
# Out:
#            COUNTRY_CODE  INF_A  INF_B  INF_ALL
# Fecha
# 2014-01-19          ESP  492.0    2.0    494.0
# 2014-02-23          ESP   67.0    3.0     70.0
# 2014-03-30          ESP   11.0    1.0     12.0
# 2014-05-04          ESP    0.0    1.0      1.0
# 2014-06-08          ESP    0.0    0.0      NaN
# ...                 ...    ...    ...      ...
# 2024-09-15          ESP    5.0    1.0      6.0
# 2024-10-20          ESP    5.0   19.0     24.0
# 2024-11-24          ESP   16.0   59.0     75.0
# 2024-12-29          ESP   94.0   71.0    165.0
# 2025-02-02          ESP  245.0  173.0    418.0
#
# [521 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(13,5))
sns.lineplot(data=flu_ESP,x=flu_ESP.index,y=flu_ESP.INF_ALL)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Temperatura Media Semanal España

# %%
#Retiro Madrid
data=pd.read_csv("./tiempo/Spain/TG_MADRID_RETIRO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_TG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_retiro=df.resample('W').mean()

#Badajoz aeropuerto
data=pd.read_csv("./tiempo/Spain/TG_BADAJOZ_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_TG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_badajoz=df.resample('W').mean()

#Estacion de Tortosa
data=pd.read_csv("./tiempo/Spain/TG_MALAGA_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_TG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_tortosa=df.resample('W').mean()

#Malaga Aeropuerto
data=pd.read_csv("./tiempo/Spain/TG_ESTACION_DE_TORTOSA.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_TG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_malaga=df.resample('W').mean()

#Puerto de Navacerrada
data=pd.read_csv("./tiempo/Spain/TG_PUERTO_DE_NAVACERRADA.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_TG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_navacerrada=df.resample('W').mean()

#Salamanca Aeropuerto
data=pd.read_csv("./tiempo/Spain/TG_SALAMANCA_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_TG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_salamanca=df.resample('W').mean()

#San Sebastian
data=pd.read_csv("./tiempo/Spain/TG_SAN_SEBASTIAN.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_TG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_san_sebastian=df.resample('W').mean()

#Zaragoza Aeropuerto
data=pd.read_csv("./tiempo/Spain/TG_ZARAGOZA_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_TG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_zaragoza=df.resample('W').mean()

#Valencia
data=pd.read_csv("./tiempo/Spain/TG_VALENCIA.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_TG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_valencia=df.resample('W').mean()

df_concat = pd.concat([df_retiro, df_badajoz,df_tortosa, df_malaga,df_salamanca,
                       df_navacerrada,df_san_sebastian,df_zaragoza,df_valencia], axis=0)
df_media_TG = df_concat.groupby(level=0).mean()
df_media_TG
# Out:
#                  STAID          TG
# DATE
# 2008-01-06  233.333333   80.277778
# 2008-01-13  233.333333   92.301587
# 2008-01-20  233.333333   97.746032
# 2008-01-27  233.333333   97.079365
# 2008-02-03  233.333333   79.777778
# ...                ...         ...
# 2025-01-05  233.333333   73.492063
# 2025-01-12  233.333333  108.984127
# 2025-01-19  233.333333   60.761905
# 2025-01-26  233.333333  106.222222
# 2025-02-02  233.333333   97.324074
#
# [892 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(13,5))
sns.lineplot(data=df_media_TG,x=df_media_TG.index,y=df_media_TG.TG)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Humedad Media España

# %%
#Retiro Madrid
data=pd.read_csv("./tiempo/Spain/HU_MADRID_RETIRO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_HU!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_retiro=df.resample('W').mean()

#Badajoz aeropuerto
data=pd.read_csv("./tiempo/Spain/HU_BADAJOZ_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_HU!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_badajoz=df.resample('W').mean()

#Estacion de Tortosa
data=pd.read_csv("./tiempo/Spain/HU_MALAGA_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_HU!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_tortosa=df.resample('W').mean()

#Malaga Aeropuerto
data=pd.read_csv("./tiempo/Spain/HU_ESTACION_DE_TORTOSA.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_HU!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_malaga=df.resample('W').mean()

#Puerto de Navacerrada
data=pd.read_csv("./tiempo/Spain/HU_PUERTO_DE_NAVACERRADA.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_HU!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_navacerrada=df.resample('W').mean()

#Salamanca Aeropuerto
data=pd.read_csv("./tiempo/Spain/HU_SALAMANCA_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_HU!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_salamanca=df.resample('W').mean()

#San Sebastian
data=pd.read_csv("./tiempo/Spain/HU_SAN_SEBASTIAN.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_HU!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_san_sebastian=df.resample('W').mean()

#Zaragoza Aeropuerto
data=pd.read_csv("./tiempo/Spain/HU_ZARAGOZA_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_HU!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_zaragoza=df.resample('W').mean()

#Valencia
data=pd.read_csv("./tiempo/Spain/HU_VALENCIA.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_HU!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_valencia=df.resample('W').mean()

df_concat = pd.concat([df_retiro, df_badajoz,df_tortosa, df_malaga,df_salamanca,
                       df_navacerrada,df_san_sebastian,df_zaragoza,df_valencia], axis=0)
df_media_HU = df_concat.groupby(level=0).mean()
df_media_HU
# Out:
#                  STAID         HU
# DATE
# 2008-01-06  233.333333  78.537037
# 2008-01-13  233.333333  79.063492
# 2008-01-20  233.333333  73.317460
# 2008-01-27  233.333333  74.222222
# 2008-02-03  233.333333  67.444444
# ...                ...        ...
# 2025-01-05  233.333333  75.174603
# 2025-01-12  233.333333  71.460317
# 2025-01-19  233.333333  58.619048
# 2025-01-26  233.333333  79.920635
# 2025-02-02  233.333333  69.583333
#
# [892 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(13,5))
sns.lineplot(data=df_media_HU,x=df_media_HU.index,y=df_media_HU.HU)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Precipitaciones Medias en España

# %%
#Retiro Madrid
data=pd.read_csv("./tiempo/Spain/RR_MADRID_RETIRO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_RR!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_retiro=df.resample('W').mean()

#Badajoz aeropuerto
data=pd.read_csv("./tiempo/Spain/RR_BADAJOZ_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_RR!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_badajoz=df.resample('W').mean()

#Estacion de Tortosa
data=pd.read_csv("./tiempo/Spain/RR_MALAGA_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_RR!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_tortosa=df.resample('W').mean()

#Malaga Aeropuerto
data=pd.read_csv("./tiempo/Spain/RR_ESTACION_DE_TORTOSA.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_RR!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_malaga=df.resample('W').mean()

#Puerto de Navacerrada
data=pd.read_csv("./tiempo/Spain/RR_PUERTO_DE_NAVACERRADA.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_RR!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_navacerrada=df.resample('W').mean()

#Salamanca Aeropuerto
data=pd.read_csv("./tiempo/Spain/RR_SALAMANCA_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_RR!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_salamanca=df.resample('W').mean()

#San Sebastian
data=pd.read_csv("./tiempo/Spain/RR_SAN_SEBASTIAN.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_RR!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_san_sebastian=df.resample('W').mean()

#Zaragoza Aeropuerto
data=pd.read_csv("./tiempo/Spain/RR_ZARAGOZA_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_RR!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_zaragoza=df.resample('W').mean()

#Valencia
data=pd.read_csv("./tiempo/Spain/RR_VALENCIA.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_RR!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_valencia=df.resample('W').mean()

df_concat = pd.concat([df_retiro, df_badajoz,df_tortosa, df_malaga,df_salamanca,
                       df_navacerrada,df_san_sebastian,df_zaragoza,df_valencia], axis=0)
df_media_RR = df_concat.groupby(level=0).mean()
df_media_RR
# Out:
#                  STAID         RR
# DATE
# 2008-01-06  233.333333  25.518519
# 2008-01-13  233.333333  21.698413
# 2008-01-20  233.333333  15.000000
# 2008-01-27  233.333333   0.111111
# 2008-02-03  233.333333  12.222222
# ...                ...        ...
# 2025-01-05  233.333333  11.113228
# 2025-01-12  233.333333  13.174603
# 2025-01-19  233.333333   4.791005
# 2025-01-26  233.333333  43.611111
# 2025-02-02  233.333333  38.185185
#
# [892 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(13,5))
sns.lineplot(data=df_media_RR,x=df_media_RR.index,y=df_media_RR.RR)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Fuerza Media del Viento en España

# %%
#Retiro Madrid
data=pd.read_csv("./tiempo/Spain/FG_MADRID_RETIRO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_FG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_retiro=df.resample('W').mean()

#Badajoz aeropuerto
data=pd.read_csv("./tiempo/Spain/FG_BADAJOZ_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_FG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_badajoz=df.resample('W').mean()

#Estacion de Tortosa
data=pd.read_csv("./tiempo/Spain/FG_MALAGA_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_FG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_tortosa=df.resample('W').mean()

#Malaga Aeropuerto
data=pd.read_csv("./tiempo/Spain/FG_ESTACION_DE_TORTOSA.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_FG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_malaga=df.resample('W').mean()

#Puerto de Navacerrada
data=pd.read_csv("./tiempo/Spain/FG_PUERTO_DE_NAVACERRADA.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_FG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_navacerrada=df.resample('W').mean()

#Salamanca Aeropuerto
data=pd.read_csv("./tiempo/Spain/FG_SALAMANCA_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_FG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_salamanca=df.resample('W').mean()

#San Sebastian
data=pd.read_csv("./tiempo/Spain/FG_SAN_SEBASTIAN.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_FG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_san_sebastian=df.resample('W').mean()

#Zaragoza Aeropuerto
data=pd.read_csv("./tiempo/Spain/FG_ZARAGOZA_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_FG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_zaragoza=df.resample('W').mean()

#Valencia
data=pd.read_csv("./tiempo/Spain/FG_VALENCIA.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_FG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_valencia=df.resample('W').mean()

df_concat = pd.concat([df_retiro, df_badajoz,df_tortosa, df_malaga,df_salamanca,
                       df_navacerrada,df_san_sebastian,df_zaragoza,df_valencia], axis=0)
df_media_FG = df_concat.groupby(level=0).mean()
df_media_FG
# Out:
#                  STAID         FG
# DATE
# 2008-01-06  233.333333  31.666667
# 2008-01-13  233.333333  30.460317
# 2008-01-20  233.333333  34.920635
# 2008-01-27  233.333333  21.253968
# 2008-02-03  233.333333  27.158730
# ...                ...        ...
# 2025-01-05  233.333333  28.714286
# 2025-01-12  233.333333  43.000000
# 2025-01-19  233.333333  23.555556
# 2025-01-26  233.333333  38.619048
# 2025-02-02  233.333333  55.314815
#
# [892 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(13,5))
sns.lineplot(data=df_media_FG,x=df_media_FG.index,y=df_media_FG.FG)
plt.xticks(rotation=90)
plt.show()

# %%
a=pd.concat([df_media_TG,df_media_HU,df_media_RR,df_media_FG],axis=1)
a=a.iloc[:,[1,3,5,7]]
a
# Out:
#                     TG         HU         RR         FG
# DATE
# 2008-01-06   80.277778  78.537037  25.518519  31.666667
# 2008-01-13   92.301587  79.063492  21.698413  30.460317
# 2008-01-20   97.746032  73.317460  15.000000  34.920635
# 2008-01-27   97.079365  74.222222   0.111111  21.253968
# 2008-02-03   79.777778  67.444444  12.222222  27.158730
# ...                ...        ...        ...        ...
# 2025-01-05   73.492063  75.174603  11.113228  28.714286
# 2025-01-12  108.984127  71.460317  13.174603  43.000000
# 2025-01-19   60.761905  58.619048   4.791005  23.555556
# 2025-01-26  106.222222  79.920635  43.611111  38.619048
# 2025-02-02   97.324074  69.583333  38.185185  55.314815
#
# [892 rows x 4 columns]

# %% [markdown]
# ### Población Total España

# %%
ine=pd.read_csv("./datos demograficos/spain_ine_1979_2025.csv")
ine['value']=ine.VALUE1*1000000+ine.VALUE2*1000+ine.VALUE3
ine2008=ine.head(43)
ine08=ine2008.sort_values(by="PERIOD", ascending=True)
ine08['Año'] = pd.to_numeric(ine08['PERIOD'].str[:4]) 
ine08['Trimestre'] = ine08['PERIOD'].str[4:]

# %%
ine08['mes']=0
for i in range(len(ine08)):
    if ine08.Trimestre[i]=='QI':
        ine08.mes[i]=1
    elif ine08.Trimestre[i]=='QII':
        ine08.mes[i]=4
    elif ine08.Trimestre[i]=='QIII':
        ine08.mes[i]=7
    else:
        ine08.mes[i]=10

# %%
import datetime
def primer_domingo_tr(anio,mes):
    fecha = datetime.date(anio, mes, 1)  # 1 del mes dado del año dado
    dias_hasta_domingo = (6 - fecha.weekday()) % 7  # Calcular días hasta el próximo domingo
    return fecha + datetime.timedelta(days=dias_hasta_domingo)

# %%
ine08['Fecha'] = pd.to_datetime(ine08.apply(lambda row: primer_domingo_tr(row['Año'], row['mes']), axis=1))

ine=ine08.iloc[:,[4,6,10]]
ine.set_index('Fecha', inplace=True)
ine
# Out:
#                     DATA TYPE       value
# Fecha
# 2008-01-06        Final value  45668938.0
# 2008-07-06        Final value  45983169.0
# 2009-01-04        Final value  46239271.0
# 2009-07-05        Final value  46367550.0
# 2010-01-03        Final value  46486621.0
# 2010-07-04        Final value  46562483.0
# 2011-01-02        Final value  46667175.0
# 2011-07-03        Final value  46736257.0
# 2012-01-01        Final value  46818216.0
# 2012-07-01        Final value  46749303.0
# 2013-01-06        Final value  46712650.0
# 2013-07-07        Final value  46581124.0
# 2014-01-05        Final value  46495744.0
# 2014-07-06        Final value  46433050.0
# 2015-01-04        Final value  46425722.0
# 2015-07-05        Final value  46384379.0
# 2016-01-03        Final value  46418884.0
# 2016-07-03        Final value  46427100.0
# 2017-01-01        Final value  46497393.0
# 2017-07-02        Final value  46510461.0
# 2018-01-07        Final value  46645070.0
# 2018-07-01        Final value  46715383.0
# 2019-01-06        Final value  46918951.0
# 2019-07-07        Final value  47087778.0
# 2020-01-05        Final value  47318050.0
# 2020-07-05        Final value  47344852.0
# 2021-01-03        Final value  47400798.0
# 2021-04-04        Final value  47356065.0
# 2021-07-04        Final value  47346836.0
# 2021-10-03        Final value  47424595.0
# 2022-01-02        Final value  47486727.0
# 2022-04-03        Final value  47609145.0
# 2022-07-03        Final value  47781354.0
# 2022-10-02        Final value  47940295.0
# 2023-01-01        Final value  48085361.0
# 2023-04-02        Final value  48205962.0
# 2023-07-02        Final value  48320520.0
# 2023-10-01        Final value  48486865.0
# 2024-01-07        Final value  48619695.0
# 2024-04-07  Provisional value  48723872.0
# 2024-07-07  Provisional value  48807137.0
# 2024-10-06  Provisional value  48962372.0
# 2025-01-05  Provisional value  49077984.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(13,5))
sns.lineplot(data=ine,x=ine.index,y=ine.value)
plt.xticks(rotation=90)
plt.show()

# %%
pd.concat([flu_ESP,a,ine],axis=1)
# Out:
#            COUNTRY_CODE  INF_A  INF_B  INF_ALL         TG         HU  \
# 2008-01-06          NaN    NaN    NaN      NaN  80.277778  78.537037
# 2008-01-13          NaN    NaN    NaN      NaN  92.301587  79.063492
# 2008-01-20          NaN    NaN    NaN      NaN  97.746032  73.317460
# 2008-01-27          NaN    NaN    NaN      NaN  97.079365  74.222222
# 2008-02-03          NaN    NaN    NaN      NaN  79.777778  67.444444
# ...                 ...    ...    ...      ...        ...        ...
# 2025-02-02          ESP  245.0  173.0    418.0  97.324074  69.583333
# 2025-02-09          ESP  245.0  144.0    389.0        NaN        NaN
# 2025-02-16          ESP  165.0   83.0    248.0        NaN        NaN
# 2025-02-23          ESP  110.0   54.0    164.0        NaN        NaN
# 2025-03-02          ESP   48.0   16.0     64.0        NaN        NaN
#
#                    RR         FG    DATA TYPE       value
# 2008-01-06  25.518519  31.666667  Final value  45668938.0
# 2008-01-13  21.698413  30.460317          NaN         NaN
# 2008-01-20  15.000000  34.920635          NaN         NaN
# 2008-01-27   0.111111  21.253968          NaN         NaN
# 2008-02-03  12.222222  27.158730          NaN         NaN
# ...               ...        ...          ...         ...
# 2025-02-02  38.185185  55.314815          NaN         NaN
# 2025-02-09        NaN        NaN          NaN         NaN
# 2025-02-16        NaN        NaN          NaN         NaN
# 2025-02-23        NaN        NaN          NaN         NaN
# 2025-03-02        NaN        NaN          NaN         NaN
#
# [896 rows x 10 columns]
