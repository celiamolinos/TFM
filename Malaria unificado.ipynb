# %%
import warnings 
warnings.filterwarnings('ignore')
from datetime import datetime, timedelta, date

# %%
import pandas as pd
dataMAL=pd.read_csv("./surveillance atlas (Hepatitis A, Nilo, Malaria)/ECDC_surveillance_data_Malaria.csv", sep=",")
dataMALRep=dataMAL[(dataMAL.Indicator=='Reported cases') & (dataMAL.NumValue!='-') & (dataMAL.RegionName=='Spain')]
dataMALRep['Time'] = pd.to_datetime(dataMALRep['Time'])
dataMALRep['NumValue'] = pd.to_numeric(dataMALRep['NumValue'])
dataMALRep.set_index('Time', inplace=True)
dataMALRep
# Out:
#            HealthTopic       Population       Indicator Unit RegionCode  \
# Time
# 2008-01-01     Malaria  Confirmed cases  Reported cases    N         ES
# 2008-02-01     Malaria  Confirmed cases  Reported cases    N         ES
# 2008-03-01     Malaria  Confirmed cases  Reported cases    N         ES
# 2008-04-01     Malaria  Confirmed cases  Reported cases    N         ES
# 2008-05-01     Malaria  Confirmed cases  Reported cases    N         ES
# ...                ...              ...             ...  ...        ...
# 2023-08-01     Malaria  Confirmed cases  Reported cases    N         ES
# 2023-09-01     Malaria  Confirmed cases  Reported cases    N         ES
# 2023-10-01     Malaria  Confirmed cases  Reported cases    N         ES
# 2023-11-01     Malaria  Confirmed cases  Reported cases    N         ES
# 2023-12-01     Malaria  Confirmed cases  Reported cases    N         ES
#
#            RegionName  NumValue  TxtValue
# Time
# 2008-01-01      Spain      17.0       NaN
# 2008-02-01      Spain      12.0       NaN
# 2008-03-01      Spain      13.0       NaN
# 2008-04-01      Spain      12.0       NaN
# 2008-05-01      Spain      16.0       NaN
# ...               ...       ...       ...
# 2023-08-01      Spain     109.0       NaN
# 2023-09-01      Spain     123.0       NaN
# 2023-10-01      Spain     130.0       NaN
# 2023-11-01      Spain      73.0       NaN
# 2023-12-01      Spain      40.0       NaN
#
# [192 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(13,5))
sns.lineplot(data=dataMALRep,x=dataMALRep.index,y=dataMALRep.NumValue)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Temperatura Media Mensual España

# %%
#Retiro Madrid
data=pd.read_csv("./tiempo/Spain/TG_MADRID_RETIRO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_TG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_retiro=df.resample('MS').mean()

#Badajoz aeropuerto
data=pd.read_csv("./tiempo/Spain/TG_BADAJOZ_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_TG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_badajoz=df.resample('MS').mean()

#Estacion de Tortosa
data=pd.read_csv("./tiempo/Spain/TG_MALAGA_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_TG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_tortosa=df.resample('MS').mean()

#Malaga Aeropuerto
data=pd.read_csv("./tiempo/Spain/TG_ESTACION_DE_TORTOSA.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_TG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_malaga=df.resample('MS').mean()

#Puerto de Navacerrada
data=pd.read_csv("./tiempo/Spain/TG_PUERTO_DE_NAVACERRADA.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_TG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_navacerrada=df.resample('MS').mean()

#Salamanca Aeropuerto
data=pd.read_csv("./tiempo/Spain/TG_SALAMANCA_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_TG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_salamanca=df.resample('MS').mean()

#San Sebastian
data=pd.read_csv("./tiempo/Spain/TG_SAN_SEBASTIAN.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_TG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_san_sebastian=df.resample('MS').mean()

#Zaragoza Aeropuerto
data=pd.read_csv("./tiempo/Spain/TG_ZARAGOZA_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_TG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_zaragoza=df.resample('MS').mean()

#Valencia
data=pd.read_csv("./tiempo/Spain/TG_VALENCIA.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_TG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_valencia=df.resample('MS').mean()

df_concat = pd.concat([df_retiro, df_badajoz,df_tortosa, df_malaga,df_salamanca,
                       df_navacerrada,df_san_sebastian,df_zaragoza,df_valencia], axis=0)
df_media_TG = df_concat.groupby(level=0).mean()
df_media_TG
# Out:
#                  STAID          TG
# DATE
# 2008-01-01  233.333333   90.860215
# 2008-02-01  233.333333  102.823755
# 2008-03-01  233.333333  110.168459
# 2008-04-01  233.333333  137.522222
# 2008-05-01  233.333333  159.813620
# ...                ...         ...
# 2024-09-01  233.333333  202.100000
# 2024-10-01  233.333333  170.530466
# 2024-11-01  233.333333  136.085185
# 2024-12-01  233.333333   88.881720
# 2025-01-01  233.333333   90.740230
#
# [205 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(13,5))
sns.lineplot(data=df_media_TG,x=df_media_TG.index,y=df_media_TG.TG)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Humedad Media Mensual España

# %%
#Retiro Madrid
data=pd.read_csv("./tiempo/Spain/HU_MADRID_RETIRO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_HU!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_retiro=df.resample('MS').mean()

#Badajoz aeropuerto
data=pd.read_csv("./tiempo/Spain/HU_BADAJOZ_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_HU!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_badajoz=df.resample('MS').mean()

#Estacion de Tortosa
data=pd.read_csv("./tiempo/Spain/HU_MALAGA_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_HU!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_tortosa=df.resample('MS').mean()

#Malaga Aeropuerto
data=pd.read_csv("./tiempo/Spain/HU_ESTACION_DE_TORTOSA.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_HU!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_malaga=df.resample('MS').mean()

#Puerto de Navacerrada
data=pd.read_csv("./tiempo/Spain/HU_PUERTO_DE_NAVACERRADA.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_HU!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_navacerrada=df.resample('MS').mean()

#Salamanca Aeropuerto
data=pd.read_csv("./tiempo/Spain/HU_SALAMANCA_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_HU!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_salamanca=df.resample('MS').mean()

#San Sebastian
data=pd.read_csv("./tiempo/Spain/HU_SAN_SEBASTIAN.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_HU!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_san_sebastian=df.resample('MS').mean()

#Zaragoza Aeropuerto
data=pd.read_csv("./tiempo/Spain/HU_ZARAGOZA_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_HU!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_zaragoza=df.resample('MS').mean()

#Valencia
data=pd.read_csv("./tiempo/Spain/HU_VALENCIA.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_HU!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_valencia=df.resample('MS').mean()

df_concat = pd.concat([df_retiro, df_badajoz,df_tortosa, df_malaga,df_salamanca,
                       df_navacerrada,df_san_sebastian,df_zaragoza,df_valencia], axis=0)
df_media_HU = df_concat.groupby(level=0).mean()
df_media_HU
# Out:
#                  STAID         HU
# DATE
# 2008-01-01  233.333333  74.630824
# 2008-02-01  233.333333  72.486590
# 2008-03-01  233.333333  61.075269
# 2008-04-01  233.333333  62.040741
# 2008-05-01  233.333333  68.611708
# ...                ...        ...
# 2024-09-01  233.333333  59.051852
# 2024-10-01  233.333333  74.745520
# 2024-11-01  233.333333  77.766667
# 2024-12-01  233.333333  73.301075
# 2025-01-01  233.333333  70.481378
#
# [205 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(13,5))
sns.lineplot(data=df_media_HU,x=df_media_HU.index,y=df_media_HU.HU)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Precipitaciones Medias Mensual en España

# %%
#Retiro Madrid
data=pd.read_csv("./tiempo/Spain/RR_MADRID_RETIRO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_RR!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_retiro=df.resample('MS').mean()

#Badajoz aeropuerto
data=pd.read_csv("./tiempo/Spain/RR_BADAJOZ_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_RR!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_badajoz=df.resample('MS').mean()

#Estacion de Tortosa
data=pd.read_csv("./tiempo/Spain/RR_MALAGA_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_RR!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_tortosa=df.resample('MS').mean()

#Malaga Aeropuerto
data=pd.read_csv("./tiempo/Spain/RR_ESTACION_DE_TORTOSA.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_RR!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_malaga=df.resample('MS').mean()

#Puerto de Navacerrada
data=pd.read_csv("./tiempo/Spain/RR_PUERTO_DE_NAVACERRADA.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_RR!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_navacerrada=df.resample('MS').mean()

#Salamanca Aeropuerto
data=pd.read_csv("./tiempo/Spain/RR_SALAMANCA_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_RR!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_salamanca=df.resample('MS').mean()

#San Sebastian
data=pd.read_csv("./tiempo/Spain/RR_SAN_SEBASTIAN.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_RR!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_san_sebastian=df.resample('MS').mean()

#Zaragoza Aeropuerto
data=pd.read_csv("./tiempo/Spain/RR_ZARAGOZA_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_RR!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_zaragoza=df.resample('MS').mean()

#Valencia
data=pd.read_csv("./tiempo/Spain/RR_VALENCIA.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_RR!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_valencia=df.resample('MS').mean()

df_concat = pd.concat([df_retiro, df_badajoz,df_tortosa, df_malaga,df_salamanca,
                       df_navacerrada,df_san_sebastian,df_zaragoza,df_valencia], axis=0)
df_media_RR = df_concat.groupby(level=0).mean()
df_media_RR
# Out:
#                  STAID         RR
# DATE
# 2008-01-01  233.333333  13.340502
# 2008-02-01  233.333333  15.088123
# 2008-03-01  233.333333  13.365114
# 2008-04-01  233.333333  26.822222
# 2008-05-01  233.333333  41.942652
# ...                ...        ...
# 2024-09-01  233.333333  21.283979
# 2024-10-01  233.333333  50.017089
# 2024-11-01  233.333333  18.043845
# 2024-12-01  233.333333  12.638349
# 2025-01-01  233.333333  21.495603
#
# [205 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(13,5))
sns.lineplot(data=df_media_RR,x=df_media_RR.index,y=df_media_RR.RR)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Fuerza Media del Viento en España Mensual

# %%
#Retiro Madrid
data=pd.read_csv("./tiempo/Spain/FG_MADRID_RETIRO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_FG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_retiro=df.resample('MS').mean()

#Badajoz aeropuerto
data=pd.read_csv("./tiempo/Spain/FG_BADAJOZ_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_FG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_badajoz=df.resample('MS').mean()

#Estacion de Tortosa
data=pd.read_csv("./tiempo/Spain/FG_MALAGA_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_FG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_tortosa=df.resample('MS').mean()

#Malaga Aeropuerto
data=pd.read_csv("./tiempo/Spain/FG_ESTACION_DE_TORTOSA.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_FG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_malaga=df.resample('MS').mean()

#Puerto de Navacerrada
data=pd.read_csv("./tiempo/Spain/FG_PUERTO_DE_NAVACERRADA.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_FG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_navacerrada=df.resample('MS').mean()

#Salamanca Aeropuerto
data=pd.read_csv("./tiempo/Spain/FG_SALAMANCA_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_FG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_salamanca=df.resample('MS').mean()

#San Sebastian
data=pd.read_csv("./tiempo/Spain/FG_SAN_SEBASTIAN.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_FG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_san_sebastian=df.resample('MS').mean()

#Zaragoza Aeropuerto
data=pd.read_csv("./tiempo/Spain/FG_ZARAGOZA_AEROPUERTO.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_FG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_zaragoza=df.resample('MS').mean()

#Valencia
data=pd.read_csv("./tiempo/Spain/FG_VALENCIA.txt", sep=",")
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_FG!=9)]
df=data.iloc[:,[0,2,3]]
dataW = df.set_index('DATE', inplace=True)
df_valencia=df.resample('MS').mean()

df_concat = pd.concat([df_retiro, df_badajoz,df_tortosa, df_malaga,df_salamanca,
                       df_navacerrada,df_san_sebastian,df_zaragoza,df_valencia], axis=0)
df_media_FG = df_concat.groupby(level=0).mean()
df_media_FG
# Out:
#                  STAID         FG
# DATE
# 2008-01-01  233.333333  28.311828
# 2008-02-01  233.333333  30.697318
# 2008-03-01  233.333333  43.698925
# 2008-04-01  233.333333  37.881481
# 2008-05-01  233.333333  32.086022
# ...                ...        ...
# 2024-09-01  233.333333  30.485185
# 2024-10-01  233.333333  32.616487
# 2024-11-01  233.333333  28.670370
# 2024-12-01  233.333333  30.530466
# 2025-01-01  233.333333  37.267050
#
# [205 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(13,5))
sns.lineplot(data=df_media_FG,x=df_media_FG.index,y=df_media_FG.FG)
plt.xticks(rotation=90)
plt.show()

# %%
a=pd.concat([df_media_TG,df_media_HU,df_media_RR,df_media_FG],axis=1)
a=a.iloc[:,[1,3,5,7]]
a
# Out:
#                     TG         HU         RR         FG
# DATE
# 2008-01-01   90.860215  74.630824  13.340502  28.311828
# 2008-02-01  102.823755  72.486590  15.088123  30.697318
# 2008-03-01  110.168459  61.075269  13.365114  43.698925
# 2008-04-01  137.522222  62.040741  26.822222  37.881481
# 2008-05-01  159.813620  68.611708  41.942652  32.086022
# ...                ...        ...        ...        ...
# 2024-09-01  202.100000  59.051852  21.283979  30.485185
# 2024-10-01  170.530466  74.745520  50.017089  32.616487
# 2024-11-01  136.085185  77.766667  18.043845  28.670370
# 2024-12-01   88.881720  73.301075  12.638349  30.530466
# 2025-01-01   90.740230  70.481378  21.495603  37.267050
#
# [205 rows x 4 columns]

# %%
ine=pd.read_csv("./datos demograficos/spain_ine_1979_2025.csv")
ine['value']=ine.VALUE1*1000000+ine.VALUE2*1000+ine.VALUE3
ine2008=ine.head(43)
ine08=ine2008.sort_values(by="PERIOD", ascending=True)
ine08['Año'] = pd.to_numeric(ine08['PERIOD'].str[:4]) 
ine08['Trimestre'] = ine08['PERIOD'].str[4:]

# %%
ine08['mes']=0
for i in range(len(ine08)):
    if ine08.Trimestre[i]=='QI':
        ine08.mes[i]=1
    elif ine08.Trimestre[i]=='QII':
        ine08.mes[i]=4
    elif ine08.Trimestre[i]=='QIII':
        ine08.mes[i]=7
    else:
        ine08.mes[i]=10

# %%
import datetime
ine08['Fecha'] = pd.to_datetime(ine08.apply(lambda row: datetime.date(row['Año'], row['mes'],1), axis=1))

ine=ine08.iloc[:,[4,6,10]]
ine.set_index('Fecha', inplace=True)
ine
# Out:
#                     DATA TYPE       value
# Fecha
# 2008-01-01        Final value  45668938.0
# 2008-07-01        Final value  45983169.0
# 2009-01-01        Final value  46239271.0
# 2009-07-01        Final value  46367550.0
# 2010-01-01        Final value  46486621.0
# 2010-07-01        Final value  46562483.0
# 2011-01-01        Final value  46667175.0
# 2011-07-01        Final value  46736257.0
# 2012-01-01        Final value  46818216.0
# 2012-07-01        Final value  46749303.0
# 2013-01-01        Final value  46712650.0
# 2013-07-01        Final value  46581124.0
# 2014-01-01        Final value  46495744.0
# 2014-07-01        Final value  46433050.0
# 2015-01-01        Final value  46425722.0
# 2015-07-01        Final value  46384379.0
# 2016-01-01        Final value  46418884.0
# 2016-07-01        Final value  46427100.0
# 2017-01-01        Final value  46497393.0
# 2017-07-01        Final value  46510461.0
# 2018-01-01        Final value  46645070.0
# 2018-07-01        Final value  46715383.0
# 2019-01-01        Final value  46918951.0
# 2019-07-01        Final value  47087778.0
# 2020-01-01        Final value  47318050.0
# 2020-07-01        Final value  47344852.0
# 2021-01-01        Final value  47400798.0
# 2021-04-01        Final value  47356065.0
# 2021-07-01        Final value  47346836.0
# 2021-10-01        Final value  47424595.0
# 2022-01-01        Final value  47486727.0
# 2022-04-01        Final value  47609145.0
# 2022-07-01        Final value  47781354.0
# 2022-10-01        Final value  47940295.0
# 2023-01-01        Final value  48085361.0
# 2023-04-01        Final value  48205962.0
# 2023-07-01        Final value  48320520.0
# 2023-10-01        Final value  48486865.0
# 2024-01-01        Final value  48619695.0
# 2024-04-01  Provisional value  48723872.0
# 2024-07-01  Provisional value  48807137.0
# 2024-10-01  Provisional value  48962372.0
# 2025-01-01  Provisional value  49077984.0

# %%
pd.concat([dataMALRep,a,ine],axis=1)
# Out:
#            HealthTopic       Population       Indicator Unit RegionCode  \
# 2008-01-01     Malaria  Confirmed cases  Reported cases    N         ES
# 2008-02-01     Malaria  Confirmed cases  Reported cases    N         ES
# 2008-03-01     Malaria  Confirmed cases  Reported cases    N         ES
# 2008-04-01     Malaria  Confirmed cases  Reported cases    N         ES
# 2008-05-01     Malaria  Confirmed cases  Reported cases    N         ES
# ...                ...              ...             ...  ...        ...
# 2024-09-01         NaN              NaN             NaN  NaN        NaN
# 2024-10-01         NaN              NaN             NaN  NaN        NaN
# 2024-11-01         NaN              NaN             NaN  NaN        NaN
# 2024-12-01         NaN              NaN             NaN  NaN        NaN
# 2025-01-01         NaN              NaN             NaN  NaN        NaN
#
#            RegionName  NumValue  TxtValue          TG         HU         RR  \
# 2008-01-01      Spain      17.0       NaN   90.860215  74.630824  13.340502
# 2008-02-01      Spain      12.0       NaN  102.823755  72.486590  15.088123
# 2008-03-01      Spain      13.0       NaN  110.168459  61.075269  13.365114
# 2008-04-01      Spain      12.0       NaN  137.522222  62.040741  26.822222
# 2008-05-01      Spain      16.0       NaN  159.813620  68.611708  41.942652
# ...               ...       ...       ...         ...        ...        ...
# 2024-09-01        NaN       NaN       NaN  202.100000  59.051852  21.283979
# 2024-10-01        NaN       NaN       NaN  170.530466  74.745520  50.017089
# 2024-11-01        NaN       NaN       NaN  136.085185  77.766667  18.043845
# 2024-12-01        NaN       NaN       NaN   88.881720  73.301075  12.638349
# 2025-01-01        NaN       NaN       NaN   90.740230  70.481378  21.495603
#
#                    FG          DATA TYPE       value
# 2008-01-01  28.311828        Final value  45668938.0
# 2008-02-01  30.697318                NaN         NaN
# 2008-03-01  43.698925                NaN         NaN
# 2008-04-01  37.881481                NaN         NaN
# 2008-05-01  32.086022                NaN         NaN
# ...               ...                ...         ...
# 2024-09-01  30.485185                NaN         NaN
# 2024-10-01  32.616487  Provisional value  48962372.0
# 2024-11-01  28.670370                NaN         NaN
# 2024-12-01  30.530466                NaN         NaN
# 2025-01-01  37.267050  Provisional value  49077984.0
#
# [205 rows x 14 columns]
