# %%
import warnings 
warnings.filterwarnings('ignore')
from datetime import datetime, timedelta, date
import re
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Lectura de los datos en bruto y eliminación de espacios
metadata=pd.read_csv("../Datos en bruto/Meteorologicos/Humedad/stations.txt",skiprows=17,sep=",")
metadata.columns=metadata.columns.str.strip()
metadata.CN=metadata.CN.str.strip()
metadata.STANAME=metadata.STANAME.str.strip()
metadata
# Out:
#       STAID                STANAME  CN        LAT         LON  HGHT
# 0         5  LINKOEPING-MALMSLAETT  SE  +58:24:00  +015:31:59    93
# 1         7       KARLSTAD-AIRPORT  SE  +59:26:40  +013:20:15   107
# 2        11  KREMSMUENSTER (TAWES)  AT  +48:03:18  +014:07:51   382
# 3        12      GRAZ-UNIVERSITAET  AT  +47:04:40  +015:26:56   367
# 4        13         INNSBRUCK-UNIV  AT  +47:15:36  +011:23:03   578
# ...     ...                    ...  ..        ...         ...   ...
# 5963  27942           BOHEMANNESET  SJ  +78:22:54  +014:45:10     8
# 5964  27943                  TOLGA  NO  +62:24:29  +010:59:43   534
# 5965  27944        E6 STORVIKEIDET  NO  +69:58:14  +023:06:29    73
# 5966  27945          E6 STOEDI BRU  NO  +66:34:40  +015:21:02   690
# 5967  27946         RV52 STORESKAR  NO  +60:52:50  +008:20:44   848
#
# [5968 rows x 6 columns]

# %%
#Filtrado de datos para España
metadata_ESP=metadata[metadata.CN=='ES']
metadata_ESP
# Out:
#       STAID                         STANAME  CN        LAT         LON  HGHT
# 128     229              BADAJOZ AEROPUERTO  ES  +38:52:59  -006:48:50   186
# 130     231               MALAGA AEROPUERTO  ES  +36:39:57  -004:28:55     7
# 131     232           PUERTO DE NAVACERRADA  ES  +40:47:35  -004:00:38  1893
# 132     233            SALAMANCA AEROPUERTO  ES  +40:57:33  -005:29:53   790
# 134     236  ESTACION DE TORTOSA (ROQUETES)  ES  +40:49:13  +000:29:35    50
# ...     ...                             ...  ..        ...         ...   ...
# 5809  27679                 MIRANDA DE EBRO  ES  +42:24:41  +002:34:24   460
# 5810  27683                     VALDEZCARAY  ES  +42:09:06  +002:34:49  1630
# 5811  27684                 MEDINA DE POMAR  ES  +42:33:03  +003:17:08   580
# 5814  27696                       BRIVIESCA  ES  +42:19:59  +003:10:59   730
# 5815  27700            SANTA GADEA DE ALFOZ  ES  +42:34:13  +003:34:21   915
#
# [875 rows x 6 columns]

# %%
#Lista de IDs de estaciones españolas
lista_estaciones_espanolas=metadata_ESP.STAID.to_list()

# %%
#Definición del dataframe con información de la primera estación
station='HU_STAID000000'
station_i=station[:-len(str(lista_estaciones_espanolas[0]))]+str(lista_estaciones_espanolas[0])
data=pd.read_csv('../Datos en bruto/Meteorologicos/Humedad/'+str(station_i)+'.txt',skiprows=20,sep=",")
data.columns=data.columns.str.strip()
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_HU!=9)]
data_unif=data.loc[:,['DATE','HU']]
data_unif.set_index('DATE', inplace=True)
data_unif
# Out:
#             HU
# DATE
# 2008-01-01  97
# 2008-01-02  82
# 2008-01-03  78
# 2008-01-04  82
# 2008-01-05  90
# ...         ..
# 2025-03-25  68
# 2025-03-26  61
# 2025-03-27  67
# 2025-03-28  61
# 2025-03-29  55
#
# [6298 rows x 1 columns]

# %%
#Anexión de la información del resto de estaciones meteorológicas
for i in lista_estaciones_espanolas[1:]:
    station='HU_STAID000000'
    station_i=station[:-len(str(i))]+str(i)
    data=pd.read_csv('../Datos en bruto/Meteorologicos/Humedad/'+station_i+'.txt',skiprows=20,sep=",")
    data.columns=data.columns.str.strip()
    data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
    data=data[(data.DATE>='2008-01-01') & (data.Q_HU!=9)]
    df=data.loc[:,['DATE','HU']]
    df.set_index('DATE', inplace=True)
    data_unif['HU '+str(i)]=df

data_unif
# Out:
#             HU  HU 231  HU 232  HU 233  HU 236  HU 237  HU 309  HU 336  \
# DATE
# 2008-01-01  97    73.0    41.0    81.0    74.0      65    68.0    72.0
# 2008-01-02  82    87.0    99.0    84.0    85.0      87    81.0    87.0
# 2008-01-03  78    70.0    98.0    84.0    98.0      64    78.0    74.0
# 2008-01-04  82    60.0    95.0    81.0    63.0      64    57.0    79.0
# 2008-01-05  90    52.0    99.0    86.0    60.0      60    49.0    76.0
# ...         ..     ...     ...     ...     ...     ...     ...     ...
# 2025-03-25  68    57.0   100.0    70.0    63.0      58    68.0    64.0
# 2025-03-26  61     NaN    91.0    69.0    48.0      56    64.0    66.0
# 2025-03-27  67    51.0    94.0    69.0    53.0      55    73.0    61.0
# 2025-03-28  61    44.0    82.0    64.0    45.0      56    64.0     NaN
# 2025-03-29  55    36.0    84.0    65.0    36.0      29    44.0     NaN
#
#             HU 337  HU 412  ...  HU 27656  HU 27665  HU 27667  HU 27670  \
# DATE                        ...
# 2008-01-01    78.0    73.0  ...      70.0       NaN       NaN       NaN
# 2008-01-02    92.0    87.0  ...      90.0       NaN       NaN       NaN
# 2008-01-03    81.0    87.0  ...      88.0       NaN       NaN       NaN
# 2008-01-04    81.0    73.0  ...      69.0       NaN       NaN       NaN
# 2008-01-05    79.0    69.0  ...      74.0       NaN       NaN       NaN
# ...            ...     ...  ...       ...       ...       ...       ...
# 2025-03-25    71.0    63.0  ...      87.0      83.0      95.0      85.0
# 2025-03-26    69.0    72.0  ...      88.0      83.0      94.0      77.0
# 2025-03-27    67.0    71.0  ...      91.0      85.0      95.0      76.0
# 2025-03-28    62.0    69.0  ...      65.0      72.0      79.0      73.0
# 2025-03-29    56.0    39.0  ...      76.0      78.0      87.0      64.0
#
#             HU 27672  HU 27679  HU 27683  HU 27684  HU 27696  HU 27700
# DATE
# 2008-01-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2008-01-02       NaN       NaN       NaN      75.0       NaN       NaN
# 2008-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2008-01-04       NaN       NaN       NaN      76.0       NaN       NaN
# 2008-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2025-03-25      79.0      81.0     100.0      77.0      86.0       NaN
# 2025-03-26      79.0      78.0     100.0      77.0      85.0       NaN
# 2025-03-27      90.0      81.0     100.0      77.0      90.0       NaN
# 2025-03-28      70.0      69.0      93.0      69.0      73.0       NaN
# 2025-03-29      71.0      70.0     100.0      60.0      72.0       NaN
#
# [6298 rows x 875 columns]

# %%
# Se eliminan todas aquellas estaciones que tienen datos faltantes y se renombra la primera estación con el IDs de estación
d=data_unif.dropna(axis=1)
d=d.rename({'HU':'HU 229'},axis=1)
d
# Out:
#             HU 229  HU 237  HU 414  HU 421  HU 3921  HU 3936  HU 3945  \
# DATE
# 2008-01-01      97      65      94      70       86       83       81
# 2008-01-02      82      87      88      89       83       66      100
# 2008-01-03      78      64      90      88       82       64       88
# 2008-01-04      82      64      82      64       92       69       82
# 2008-01-05      90      60      95      55       88       74       94
# ...            ...     ...     ...     ...      ...      ...      ...
# 2025-03-25      68      58      83      59       69       84       56
# 2025-03-26      61      56      85      55       61       80       62
# 2025-03-27      67      55      85      52       65       77       65
# 2025-03-28      61      56      73      43       61       71       52
# 2025-03-29      55      29      69      29       54       58       51
#
#             HU 3946  HU 3959  HU 3961  HU 3971  HU 26913  HU 26984  HU 27045  \
# DATE
# 2008-01-01       77       55       64       64        55        67        69
# 2008-01-02       87       56       76       87        56        79        54
# 2008-01-03       85       56       80       70        56        94        67
# 2008-01-04       76       62       77       72        62        85        70
# 2008-01-05       82       64       94       75        64        81        68
# ...             ...      ...      ...      ...       ...       ...       ...
# 2025-03-25       66       67       83       75        69        85        86
# 2025-03-26       67       53       75       69        58        77        78
# 2025-03-27       66       60       73       71        62        77        79
# 2025-03-28       57       66       69       59        65        80        77
# 2025-03-29       55       70       66       52        71        45        72
#
#             HU 27232  HU 27422
# DATE
# 2008-01-01        76        78
# 2008-01-02        92        85
# 2008-01-03        91        76
# 2008-01-04        78        59
# 2008-01-05        86        54
# ...              ...       ...
# 2025-03-25        62        65
# 2025-03-26        61        61
# 2025-03-27        64        44
# 2025-03-28        56        42
# 2025-03-29        55        32
#
# [6298 rows x 16 columns]

# %%
# Lista de estaciones españolas sin valores faltantes
v=[]
for i in d.columns:
    v.append(int(i[3:]))
    
mt=metadata_ESP[metadata_ESP.STAID.isin(v)]
mt
# Out:
#       STAID                              STANAME  CN        LAT         LON  \
# 128     229                   BADAJOZ AEROPUERTO  ES  +38:52:59  -006:48:50
# 135     237                             VALENCIA  ES  +39:28:50  -000:21:59
# 189     414                    BURGOS AEROPUERTO  ES  +42:21:24  -003:37:13
# 196     421                               MURCIA  ES  +38:00:06  -001:10:14
# 620    3921                              CACERES  ES  +39:28:17  -006:20:20
# 635    3936  DONOSTIA / SAN SEBASTIAN AEROPUERTO  ES  +43:21:24  -001:47:31
# 643    3945                       COLMENAR VIEJO  ES  +40:41:45  -003:45:54
# 644    3946                    MADRID AEROPUERTO  ES  +40:28:00  -003:33:20
# 656    3959                 STA.CRUZ DE TENERIFE  ES  +28:27:47  -016:15:19
# 658    3961                              SEGOVIA  ES  +40:56:43  -004:07:35
# 668    3971                               DAROCA  ES  +41:06:51  -001:24:36
# 5073  26913                                ANAGA  ES  +28:30:29  -016:11:44
# 5144  26984                    CALDES DE MONTBUI  ES  +41:36:46  +002:10:05
# 5205  27045                 SANTANDER AEROPUERTO  ES  +43:25:42  -003:49:53
# 5392  27232                   POZUELO DE ALARCON  ES  +40:26:53  -003:48:47
# 5581  27422                               MALAGA  ES  +36:43:00  -004:25:10
#
#       HGHT
# 128    186
# 135     11
# 189    891
# 196     62
# 620    394
# 635      4
# 643   1004
# 644    609
# 656     36
# 658   1008
# 668    774
# 5073    19
# 5144   175
# 5205     3
# 5392   665
# 5581    25

# %%
capitales_provinciales = ["ALAVA", "ALBACETE", "ALICANTE", "ALMERIA", "OVIEDO", "AVILA", "BADAJOZ",
    "BARCELONA", "BURGOS", "CACERES", "CADIZ", "SANTANDER", "CASTELLON",
    "CIUDAD REAL", "CORDOBA", "CUENCA", "GIRONA", "GRANADA", "GUADALAJARA",
    "SAN SEBASTIAN", "HUELVA", "HUESCA", "PALMA", "JAEN", "A CORUNA",
    "LOGRONO", "LAS PALMAS DE GRAN CANARIA", "LEON", "LLEIDA", "LUGO",
    "MADRID", "MALAGA", "MURCIA", "PAMPLONA", "OURENSE", "PALENCIA",
    "PONTEVEDRA", "SALAMANCA", "STA.CRUZ DE TENERIFE", "SEGOVIA",
    "SEVILLA", "SORIA", "TARRAGONA", "TERUEL", "TOLEDO", "VALENCIA",
    "VALLADOLID", "BILBAO", "ZAMORA", "ZARAGOZA"]

# %%
# Filtrado de estaciones sin valores faltantes relativas a una provincia 
esp=mt[mt.STANAME.isin(capitales_provinciales)]
esp
# Out:
#       STAID               STANAME  CN        LAT         LON  HGHT
# 135     237              VALENCIA  ES  +39:28:50  -000:21:59    11
# 196     421                MURCIA  ES  +38:00:06  -001:10:14    62
# 620    3921               CACERES  ES  +39:28:17  -006:20:20   394
# 656    3959  STA.CRUZ DE TENERIFE  ES  +28:27:47  -016:15:19    36
# 658    3961               SEGOVIA  ES  +40:56:43  -004:07:35  1008
# 5581  27422                MALAGA  ES  +36:43:00  -004:25:10    25

# %%
#Agrupación de los datos diarios en datos semanales para cada estación
data=d.loc[:,['HU '+str(i) for i in esp.STAID.to_list()]]
data=data.resample('MS').mean()
data
# Out:
#                HU 237     HU 421    HU 3921    HU 3959    HU 3961   HU 27422
# DATE
# 2008-01-01  68.387097  66.580645  80.612903  58.483871  70.322581  72.548387
# 2008-02-01  77.482759  79.068966  76.000000  64.896552  60.827586  77.862069
# 2008-03-01  51.806452  54.516129  60.258065  60.838710  60.645161  58.161290
# 2008-04-01  56.633333  53.400000  61.666667  54.966667  56.733333  60.700000
# 2008-05-01  71.419355  64.193548  67.258065  56.516129  64.935484  67.645161
# ...               ...        ...        ...        ...        ...        ...
# 2024-11-01  66.433333  69.266667  81.533333  60.200000  69.200000  73.666667
# 2024-12-01  56.451613  57.903226  78.129032  61.193548  75.451613  64.225806
# 2025-01-01  52.451613  55.290323  80.129032  64.870968  71.032258  60.516129
# 2025-02-01  62.107143  60.821429  77.285714  64.214286  68.821429  67.000000
# 2025-03-01  62.413793  67.965517  78.068966  60.724138  75.965517  68.000000
#
# [207 rows x 6 columns]

# %%
#Cálculo de la media para cada mes en función del total de estaciones
a=data.mean(axis=1)
a=pd.DataFrame(a).rename({0:'HU'},axis=1)
a
# Out:
#                    HU
# DATE
# 2008-01-01  69.489247
# 2008-02-01  72.689655
# 2008-03-01  57.704301
# 2008-04-01  57.350000
# 2008-05-01  65.327957
# ...               ...
# 2024-11-01  70.050000
# 2024-12-01  65.559140
# 2025-01-01  64.048387
# 2025-02-01  66.708333
# 2025-03-01  68.856322
#
# [207 rows x 1 columns]

# %%
a.to_csv('humedad_mensual_esp.csv',index=True,encoding='utf-8')

# %%
#Visualización de datos mensuales
plt.figure(figsize=(13,5))
sns.lineplot(data=a,x=a.index,y=a.HU)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Transformación de longitudes y latitudes para exportación de datos para visualización de estaciones

# %%
def dms_a_decimal(dms_str):
    # Quitar el signo y dividir en partes
    signo = -1 if dms_str.startswith("-") else 1
    partes = dms_str.lstrip("+-").split(":")
    grados, minutos, segundos = map(float, partes)
    decimal = signo * (grados + minutos / 60 + segundos / 3600)
    return decimal

# %%
esp['LAT'] = esp['LAT'].apply(dms_a_decimal)
esp['LON'] = esp['LON'].apply(dms_a_decimal)

# %%
#esp.to_csv('estaciones.csv',index=True,encoding='utf-8')
