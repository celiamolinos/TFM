# %%
import warnings 
warnings.filterwarnings('ignore')
from datetime import datetime, timedelta, date
import re
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Lectura de los datos en bruto y eliminación de espacios
metadata=pd.read_csv("../Datos en bruto/Meteorologicos/Temperatura/stations.txt",skiprows=17,sep=",")
metadata.columns=metadata.columns.str.strip()
metadata.CN=metadata.CN.str.strip()
metadata.STANAME=metadata.STANAME.str.strip()
metadata
# Out:
#       STAID                STANAME  CN        LAT         LON  HGHT
# 0         1                VAEXJOE  SE  +56:52:00  +014:48:00   166
# 1         2                  FALUN  SE  +60:37:00  +015:37:00   160
# 2         3               STENSELE  SE  +65:04:00  +017:09:59   325
# 3         4             LINKOEPING  SE  +58:24:00  +015:31:59    93
# 4         5  LINKOEPING-MALMSLAETT  SE  +58:24:00  +015:31:59    93
# ...     ...                    ...  ..        ...         ...   ...
# 9698  27950         E6 SEFRIVATNET  NO  +65:15:11  +013:18:55   308
# 9699  27951           E6 HANSMYRAN  NO  +65:12:07  +013:22:45   368
# 9700  27952       FV659 REMMEFJELL  NO  +62:32:26  +006:28:45   124
# 9701  27953              E75 DOMEN  NO  +70:20:02  +031:01:26   103
# 9702  27954          RV9 HOVDEN II  NO  +59:31:37  +007:22:17   772
#
# [9703 rows x 6 columns]

# %%
#Filtrado de datos para España
metadata_ESP=metadata[metadata.CN=='ES']
metadata_ESP
# Out:
#       STAID                STANAME  CN        LAT         LON  HGHT
# 183     229     BADAJOZ AEROPUERTO  ES  +38:52:59  -006:48:50   186
# 185     231      MALAGA AEROPUERTO  ES  +36:39:57  -004:28:55     7
# 186     232  PUERTO DE NAVACERRADA  ES  +40:47:35  -004:00:38  1893
# 187     233   SALAMANCA AEROPUERTO  ES  +40:57:33  -005:29:53   790
# 189     235             TORREVIEJA  ES  +37:58:37  -000:42:38     1
# ...     ...                    ...  ..        ...         ...   ...
# 9490  27679        MIRANDA DE EBRO  ES  +42:24:41  +002:34:24   460
# 9491  27683            VALDEZCARAY  ES  +42:09:06  +002:34:49  1630
# 9492  27684        MEDINA DE POMAR  ES  +42:33:03  +003:17:08   580
# 9495  27696              BRIVIESCA  ES  +42:19:59  +003:10:59   730
# 9496  27700   SANTA GADEA DE ALFOZ  ES  +42:34:13  +003:34:21   915
#
# [880 rows x 6 columns]

# %%
#Lista de IDs de estaciones españolas
lista_estaciones_espanolas=metadata_ESP.STAID.to_list()

# %%
#Definición del dataframe con información de la primera estación
station='TG_STAID000000'
station_i=station[:-len(str(lista_estaciones_espanolas[0]))]+str(lista_estaciones_espanolas[0])
data=pd.read_csv('../Datos en bruto/Meteorologicos/Temperatura/'+str(station_i)+'.txt',skiprows=20,sep=",")
data.columns=data.columns.str.strip()
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_TG!=9)]
data_unif=data.loc[:,['DATE','TG']]
data_unif.set_index('DATE', inplace=True)
data_unif
# Out:
#              TG
# DATE
# 2008-01-01   67
# 2008-01-02  127
# 2008-01-03   90
# 2008-01-04   91
# 2008-01-05  106
# ...         ...
# 2025-03-25  132
# 2025-03-26  134
# 2025-03-27  128
# 2025-03-28  152
# 2025-03-29  158
#
# [6298 rows x 1 columns]

# %%
#Anexión de la información del resto de estaciones meteorológicas
for i in lista_estaciones_espanolas[1:]:
    station='TG_STAID000000'
    station_i=station[:-len(str(i))]+str(i)
    data=pd.read_csv('../Datos en bruto/Meteorologicos/Temperatura/'+station_i+'.txt',skiprows=20,sep=",")
    data.columns=data.columns.str.strip()
    data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
    data=data[(data.DATE>='2008-01-01') & (data.Q_TG!=9)]
    df=data.loc[:,['DATE','TG']]
    df.set_index('DATE', inplace=True)
    data_unif['TG '+str(i)]=df

data_unif
# Out:
#              TG  TG 231  TG 232  TG 233  TG 235  TG 236  TG 237  TG 309  \
# DATE
# 2008-01-01   67     125      20    32.0   120.0      52     107    88.0
# 2008-01-02  127     115     -14    76.0    98.0      50      93    74.0
# 2008-01-03   90     122     -24    43.0   115.0      60     122    80.0
# 2008-01-04   91     109     -22    56.0   125.0      90     122    96.0
# 2008-01-05  106     122      12    86.0   140.0     130     131   130.0
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 2025-03-25  132     164       0    82.0     NaN     162     147   147.0
# 2025-03-26  134     158       5    82.0     NaN     160     154   146.0
# 2025-03-27  128     168      10    72.0     NaN     156     142   140.0
# 2025-03-28  152     186      16    81.0     NaN     160     151   154.0
# 2025-03-29  158     211       8    74.0     NaN     152     178   172.0
#
#             TG 336  TG 337  ...  TG 27664  TG 27665  TG 27667  TG 27670  \
# DATE                        ...
# 2008-01-01    31.0    72.0  ...       NaN       NaN       NaN       NaN
# 2008-01-02    67.0   106.0  ...       NaN       NaN       NaN       NaN
# 2008-01-03    76.0    99.0  ...       NaN       NaN       NaN       NaN
# 2008-01-04    46.0   100.0  ...       NaN       NaN       NaN       NaN
# 2008-01-05    64.0    88.0  ...       NaN       NaN       NaN       NaN
# ...            ...     ...  ...       ...       ...       ...       ...
# 2025-03-25   114.0   122.0  ...      88.0      90.0      59.0      74.0
# 2025-03-26    91.0   130.0  ...      84.0      86.0      34.0      58.0
# 2025-03-27    92.0   142.0  ...      82.0      84.0      39.0      64.0
# 2025-03-28     NaN   145.0  ...     101.0      98.0      64.0      53.0
# 2025-03-29     NaN   154.0  ...      81.0      77.0      56.0      40.0
#
#             TG 27672  TG 27679  TG 27683  TG 27684  TG 27696  TG 27700
# DATE
# 2008-01-01      30.0      16.0       NaN       NaN       NaN       NaN
# 2008-01-02       5.0       1.0       NaN       NaN       NaN       NaN
# 2008-01-03       NaN      28.0       NaN       NaN       NaN       NaN
# 2008-01-04       NaN      62.0       NaN       NaN       NaN       NaN
# 2008-01-05       NaN     100.0       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2025-03-25      88.0     103.0      10.0      88.0      81.0      58.0
# 2025-03-26      78.0      92.0      -4.0      64.0      68.0      44.0
# 2025-03-27      67.0      84.0      -3.0      63.0      66.0      46.0
# 2025-03-28      90.0     100.0      10.0      77.0      80.0      53.0
# 2025-03-29      76.0      86.0     -12.0      82.0      66.0      51.0
#
# [6298 rows x 880 columns]

# %%
# Se eliminan todas aquellas estaciones que tienen datos faltantes y se renombra la primera estación con el IDs de estación
d=data_unif.dropna(axis=1)
d=d.rename({'TG':'TG 229'},axis=1)
d
# Out:
#             TG 229  TG 231  TG 232  TG 236  TG 237  TG 420  TG 421  TG 425  \
# DATE
# 2008-01-01      67     125      20      52     107     108      84      -7
# 2008-01-02     127     115     -14      50      93     118      56      54
# 2008-01-03      90     122     -24      60     122     102      77      56
# 2008-01-04      91     109     -22      90     122     108      84      54
# 2008-01-05     106     122      12     130     131     145     110      83
# ...            ...     ...     ...     ...     ...     ...     ...     ...
# 2025-03-25     132     164       0     162     147     131     154      90
# 2025-03-26     134     158       5     160     154     126     161      90
# 2025-03-27     128     168      10     156     142     119     167      76
# 2025-03-28     152     186      16     160     151     122     172      90
# 2025-03-29     158     211       8     152     178     129     182      84
#
#             TG 1393  TG 1396  ...  TG 26978  TG 26979  TG 26989  TG 27045  \
# DATE                          ...
# 2008-01-01       56       -8  ...        26        26        15        46
# 2008-01-02      127       40  ...        45        45        16       139
# 2008-01-03      100       66  ...        46        46        39       107
# 2008-01-04       96       28  ...        53        53        48        98
# 2008-01-05      138       91  ...        64        64        56       148
# ...             ...      ...  ...       ...       ...       ...       ...
# 2025-03-25      126      118  ...        86        86        63       127
# 2025-03-26      113      122  ...       104       104        80       104
# 2025-03-27      115      119  ...        80        80        72       105
# 2025-03-28      121      113  ...        99        99        76       124
# 2025-03-29      106      116  ...        90        90        84       112
#
#             TG 27046  TG 27106  TG 27232  TG 27422  TG 27610  TG 27631
# DATE
# 2008-01-01        69       108        31       138        38        28
# 2008-01-02       119       116        62       120        46        28
# 2008-01-03       112        86        57       132        53        57
# 2008-01-04       112        88        68       121        44        62
# 2008-01-05       144       132        50       135        70        88
# ...              ...       ...       ...       ...       ...       ...
# 2025-03-25       122       137       108       155        94       124
# 2025-03-26       120       128        92       164       102       102
# 2025-03-27       114       119        85       196        96       100
# 2025-03-28       120       138       104       192       102       110
# 2025-03-29       117       154       108       216        90        98
#
# [6298 rows x 43 columns]

# %%
# Lista de estaciones españolas sin valores faltantes
v=[]
for i in d.columns:
    v.append(int(i[3:]))
    
mt=metadata_ESP[metadata_ESP.STAID.isin(v)]
mt
# Out:
#       STAID                         STANAME  CN        LAT         LON  HGHT
# 183     229              BADAJOZ AEROPUERTO  ES  +38:52:59  -006:48:50   186
# 185     231               MALAGA AEROPUERTO  ES  +36:39:57  -004:28:55     7
# 186     232           PUERTO DE NAVACERRADA  ES  +40:47:35  -004:00:38  1893
# 190     236  ESTACION DE TORTOSA (ROQUETES)  ES  +40:49:13  +000:29:35    50
# 191     237                        VALENCIA  ES  +39:28:50  -000:21:59    11
# 312     420                        A CORUNA  ES  +43:21:56  -008:25:17    57
# 313     421                          MURCIA  ES  +38:00:06  -001:10:14    62
# 317     425                      VALLADOLID  ES  +41:38:26  -004:45:15   734
# 629    1393               BILBAO AEROPUERTO  ES  +43:17:53  -002:54:23    42
# 632    1396                      PONFERRADA  ES  +42:33:50  -006:36:00   532
# 636    1401                 REUS AEROPUERTO  ES  +41:08:58  +001:10:44    71
# 1298   3839               TORREJON DE ARDOZ  ES  +40:29:18  -003:26:36   607
# 1306   3910                           GIJON  ES  +43:32:20  -005:38:15     3
# 1307   3911                GIJON. LA MERCED  ES  +43:32:30  -005:39:42    22
# 1310   3914                           AVILA  ES  +40:39:33  -004:40:46  1130
# 1317   3921                         CACERES  ES  +39:28:17  -006:20:20   394
# 1318   3922                       SANTANDER  ES  +43:29:27  -003:48:02    52
# 1319   3923            SANTANDER AEROPUERTO  ES  +43:25:26  -003:49:32     3
# 1325   3929                          CUENCA  ES  +40:04:01  -002:07:54   949
# 1336   3942                          LLEIDA  ES  +41:37:33  +000:35:53   186
# 1340   3946               MADRID AEROPUERTO  ES  +40:28:00  -003:33:20   609
# 1342   3948                          GETAFE  ES  +40:17:57  -003:43:19   620
# 1353   3959            STA.CRUZ DE TENERIFE  ES  +28:27:47  -016:15:19    36
# 1365   3971                          DAROCA  ES  +41:06:51  -001:24:36   774
# 3903  10904               LLEIDA-AJUNTAMENT  ES  +41:36:59  +000:34:59   169
# 3904  10905               LLEIDA-ESCORXADOR  ES  +41:36:48  +000:37:05   162
# 3936  11034            EL PRAT DE LLOBREGAT  ES  +41:20:25  +002:04:49     8
# 3944  11042              HORTA DE SANT JOAN  ES  +40:57:05  +000:18:20   515
# 3984  11082                     ULLDEMOLINS  ES  +41:19:12  +000:53:08   687
# 3987  11085                        VILADRAU  ES  +41:50:24  +002:25:06   953
# 7974  25164    PORT DE BARCELONA - ZAL PRAT  ES  +41:19:09  +002:08:12     7
# 8751  26913                           ANAGA  ES  +28:30:29  -016:11:44    19
# 8806  26968                       TARRAGONA  ES  +41:07:26  +001:14:57    55
# 8816  26978                      MONTSERRAT  ES  +41:35:39  +001:50:21   738
# 8817  26979         MONISTROL DE MONTSERRAT  ES  +41:35:39  +001:50:21   738
# 8827  26989              FOGARS DE MONTCLUS  ES  +41:45:36  +002:25:51   936
# 8883  27045            SANTANDER AEROPUERTO  ES  +43:25:42  -003:49:53     3
# 8884  27046                       SANTANDER  ES  +43:29:27  -003:48:02    51
# 8944  27106            VILAGARCIA DE AROUSA  ES  +42:35:04  -008:46:28    32
# 9070  27232              POZUELO DE ALARCON  ES  +40:26:53  -003:48:47   665
# 9260  27422                          MALAGA  ES  +36:43:00  -004:25:10    25
# 9448  27610            LA POBLA DE CERVOLES  ES  +41:21:57  +000:54:48   673
# 9469  27631              HORTA DE SANT JOAN  ES  +40:57:11  +000:18:42   495

# %%
capitales_provinciales = ["ALAVA", "ALBACETE", "ALICANTE", "ALMERIA", "OVIEDO", "AVILA", "BADAJOZ",
    "BARCELONA", "BURGOS", "CACERES", "CADIZ", "SANTANDER", "CASTELLON",
    "CIUDAD REAL", "CORDOBA", "CUENCA", "GIRONA", "GRANADA", "GUADALAJARA",
    "SAN SEBASTIAN", "HUELVA", "HUESCA", "PALMA", "JAEN", "A CORUNA",
    "LOGRONO", "LAS PALMAS DE GRAN CANARIA", "LEON", "LLEIDA", "LUGO",
    "MADRID", "MALAGA", "MURCIA", "PAMPLONA", "OURENSE", "PALENCIA",
    "PONTEVEDRA", "SALAMANCA", "STA.CRUZ DE TENERIFE", "SEGOVIA",
    "SEVILLA", "SORIA", "TARRAGONA", "TERUEL", "TOLEDO", "VALENCIA",
    "VALLADOLID", "BILBAO", "ZAMORA", "ZARAGOZA"]

# %%
# Filtrado de estaciones sin valores faltantes relativas a una provincia 
esp=mt[mt.STANAME.isin(capitales_provinciales)]
esp
# Out:
#       STAID               STANAME  CN        LAT         LON  HGHT
# 191     237              VALENCIA  ES  +39:28:50  -000:21:59    11
# 312     420              A CORUNA  ES  +43:21:56  -008:25:17    57
# 313     421                MURCIA  ES  +38:00:06  -001:10:14    62
# 317     425            VALLADOLID  ES  +41:38:26  -004:45:15   734
# 1310   3914                 AVILA  ES  +40:39:33  -004:40:46  1130
# 1317   3921               CACERES  ES  +39:28:17  -006:20:20   394
# 1318   3922             SANTANDER  ES  +43:29:27  -003:48:02    52
# 1325   3929                CUENCA  ES  +40:04:01  -002:07:54   949
# 1336   3942                LLEIDA  ES  +41:37:33  +000:35:53   186
# 1353   3959  STA.CRUZ DE TENERIFE  ES  +28:27:47  -016:15:19    36
# 8806  26968             TARRAGONA  ES  +41:07:26  +001:14:57    55
# 8884  27046             SANTANDER  ES  +43:29:27  -003:48:02    51
# 9260  27422                MALAGA  ES  +36:43:00  -004:25:10    25

# %%
#Agrupación de los datos diarios en datos mensuales para cada estación
data=d.loc[:,['TG '+str(i) for i in esp.STAID.to_list()]]
data=data.resample('MS').mean()
data
# Out:
#                 TG 237      TG 420      TG 421      TG 425     TG 3914  \
# DATE
# 2008-01-01  131.967742  121.000000  117.903226   56.612903   59.677419
# 2008-02-01  132.068966  140.793103  129.448276   78.206897   67.275862
# 2008-03-01  155.774194  119.709677  158.483871   80.193548   65.483871
# 2008-04-01  175.300000  137.666667  178.300000  111.433333   99.366667
# 2008-05-01  187.838710  154.483871  199.774194  139.774194  119.064516
# ...                ...         ...         ...         ...         ...
# 2024-11-01  179.833333  163.766667  181.700000  114.500000  104.100000
# 2024-12-01  135.935484  123.451613  131.516129   49.967742   50.870968
# 2025-01-01  141.290323  124.064516  127.967742   63.354839   49.258065
# 2025-02-01  140.071429  131.071429  140.071429   75.178571   67.250000
# 2025-03-01  143.448276  123.517241  149.068966   79.172414   57.206897
#
#                TG 3921     TG 3922     TG 3929     TG 3942     TG 3959  \
# DATE
# 2008-01-01   96.645161  116.258065   70.967742   63.000000  192.032258
# 2008-02-01  108.000000  122.068966   79.172414   97.172414  192.724138
# 2008-03-01  117.806452  113.967742   91.032258  115.129032  189.806452
# 2008-04-01  145.733333  125.166667  118.233333  146.133333  214.300000
# 2008-05-01  160.645161  154.290323  141.225806  178.000000  220.548387
# ...                ...         ...         ...         ...         ...
# 2024-11-01  142.900000  156.766667  116.466667  119.733333  232.633333
# 2024-12-01   91.193548  116.709677   66.903226   67.645161  206.032258
# 2025-01-01   96.903226  118.451613   62.032258   68.645161  194.419355
# 2025-02-01  107.642857  123.500000   80.107143   88.178571  190.142857
# 2025-03-01  110.206897  123.551724   76.172414  110.241379  193.689655
#
#               TG 26968    TG 27046    TG 27422
# DATE
# 2008-01-01   91.548387  116.258065  142.548387
# 2008-02-01   98.103448  122.068966  155.862069
# 2008-03-01  114.580645  113.967742  167.903226
# 2008-04-01  137.466667  125.166667  177.966667
# 2008-05-01  158.419355  154.290323  200.967742
# ...                ...         ...         ...
# 2024-11-01  161.000000  156.766667  190.866667
# 2024-12-01  119.645161  116.709677  154.838710
# 2025-01-01  119.935484  118.451613  151.096774
# 2025-02-01  117.535714  123.500000  151.607143
# 2025-03-01  127.724138  123.551724  159.482759
#
# [207 rows x 13 columns]

# %%
#Cálculo de la media para cada semana en función del total de estaciones
a=data.mean(axis=1)
a=pd.DataFrame(a).rename({0:'TG'},axis=1)
a
# Out:
# DATE
# 2008-01-01    105.878412
# 2008-02-01    117.151194
# 2008-03-01    123.372208
# 2008-04-01    145.556410
# 2008-05-01    166.870968
#                  ...
# 2024-11-01    155.464103
# 2024-12-01    110.109181
# 2025-01-01    110.451613
# 2025-02-01    118.142857
# 2025-03-01    121.310345
# Freq: MS, Length: 207, dtype: float64

# %%
#Visualización de datos mensuales
plt.figure(figsize=(13,5))
sns.lineplot(data=a,x=a.index,y=a)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Transformación de longitudes y latitudes para exportación de datos para visualización de estaciones

# %%
def dms_a_decimal(dms_str):
    # Quitar el signo y dividir en partes
    signo = -1 if dms_str.startswith("-") else 1
    partes = dms_str.lstrip("+-").split(":")
    grados, minutos, segundos = map(float, partes)
    decimal = signo * (grados + minutos / 60 + segundos / 3600)
    return decimal

# %%
esp['LAT'] = esp['LAT'].apply(dms_a_decimal)
esp['LON'] = esp['LON'].apply(dms_a_decimal)

# %%
#esp.to_csv('estaciones_temp_esp.csv',index=True,encoding='utf-8')
