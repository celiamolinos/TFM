# %%
import warnings 
warnings.filterwarnings('ignore')
from datetime import datetime, timedelta, date
import re
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
from shapely.geometry import Point
import math

# %%
#Lectura de los datos de estaciones en bruto y eliminación de espacios
metadata=pd.read_csv("../Datos en bruto/Meteorologicos/Temperatura/stations.txt",skiprows=17,sep=",")
metadata.columns=metadata.columns.str.strip()
metadata.CN=metadata.CN.str.strip()
metadata.STANAME=metadata.STANAME.str.strip()
metadata
# Out:
#       STAID                STANAME  CN        LAT         LON  HGHT
# 0         1                VAEXJOE  SE  +56:52:00  +014:48:00   166
# 1         2                  FALUN  SE  +60:37:00  +015:37:00   160
# 2         3               STENSELE  SE  +65:04:00  +017:09:59   325
# 3         4             LINKOEPING  SE  +58:24:00  +015:31:59    93
# 4         5  LINKOEPING-MALMSLAETT  SE  +58:24:00  +015:31:59    93
# ...     ...                    ...  ..        ...         ...   ...
# 9698  27950         E6 SEFRIVATNET  NO  +65:15:11  +013:18:55   308
# 9699  27951           E6 HANSMYRAN  NO  +65:12:07  +013:22:45   368
# 9700  27952       FV659 REMMEFJELL  NO  +62:32:26  +006:28:45   124
# 9701  27953              E75 DOMEN  NO  +70:20:02  +031:01:26   103
# 9702  27954          RV9 HOVDEN II  NO  +59:31:37  +007:22:17   772
#
# [9703 rows x 6 columns]

# %%
#Filtrado de datos para Italia
metadata_IT=metadata[metadata.CN=='IT']
metadata_IT
# Out:
#       STAID                                   STANAME  CN        LAT  \
# 130     169                                   BOLOGNA  IT  +44:30:00
# 131     170                                   FERRARA  IT  +44:49:57
# 132     173                                     MILAN  IT  +45:28:18
# 133     174                                  BRINDISI  IT  +40:37:59
# 134     175                                  CAGLIARI  IT  +39:13:59
# ...     ...                                       ...  ..        ...
# 9682  27908       MONDEVAL DI SOPRA (SELVA DI CADORE)  IT  +46:27:51
# 9683  27909                          PASSO CIMABANCHE  IT  +46:37:14
# 9684  27910  ROVINA DI CANCIA (BORCA DI CADORE Q1335)  IT  +46:26:13
# 9685  27911                      MONTE GRANDE (TEOLO)  IT  +45:21:42
# 9686  27912                              MONTE VERENA  IT  +45:55:50
#
#              LON  HGHT
# 130   +011:20:45    53
# 131   +011:37:15    15
# 132   +009:11:21   150
# 133   +017:55:59    10
# 134   +009:03:00    21
# ...          ...   ...
# 9682  +012:06:03  2175
# 9683  +012:11:02  1532
# 9684  +012:14:34  1335
# 9685  +011:40:22   465
# 9686  +011:24:50  2008
#
# [858 rows x 6 columns]

# %%
#Lista de IDs de estaciones italianas
lista_estaciones_italianas=metadata_IT.STAID.to_list()

# %%
#Definición del dataframe con información de la primera estación
station='TG_STAID000000'
station_i=station[:-len(str(lista_estaciones_italianas[0]))]+str(lista_estaciones_italianas[0])
data=pd.read_csv('../Datos en bruto/Meteorologicos/Temperatura/'+str(station_i)+'.txt',skiprows=20,sep=",")
data.columns=data.columns.str.strip()
data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
data=data[(data.DATE>='2008-01-01') & (data.Q_TG!=9) & (data.DATE<'2025-01-01')]
data_unif=data.loc[:,['DATE','TG']]
data_unif.set_index('DATE', inplace=True)
data_unif
# Out:
#             TG
# DATE
# 2008-01-01  29
# 2008-01-02  34
# 2008-01-03  17
# 2008-01-04  21
# 2008-01-05  39
# ...         ..
# 2024-12-27  31
# 2024-12-28  43
# 2024-12-29  45
# 2024-12-30  42
# 2024-12-31  41
#
# [6161 rows x 1 columns]

# %%
#Anexión de la información del resto de estaciones meteorológicas
for i in lista_estaciones_italianas[1:]:
    station='TG_STAID000000'
    station_i=station[:-len(str(i))]+str(i)
    data=pd.read_csv('../Datos en bruto/Meteorologicos/Temperatura/'+station_i+'.txt',skiprows=20,sep=",")
    data.columns=data.columns.str.strip()
    data['DATE'] = pd.to_datetime(data['DATE'],format='%Y%m%d')
    data=data[(data.DATE>='2008-01-01') & (data.Q_TG!=9) & (data.DATE<'2025-01-01')]
    df=data.loc[:,['DATE','TG']]
    df.set_index('DATE', inplace=True)
    data_unif['TG '+str(i)]=df

data_unif
# Out:
#             TG  TG 170  TG 173  TG 174  TG 175  TG 176  TG 177  TG 380  \
# DATE
# 2008-01-01  29    25.0    62.0    56.0    85.0    51.0    17.0     NaN
# 2008-01-02  34    16.0    56.0    51.0    90.0    38.0    16.0     NaN
# 2008-01-03  17     5.0    35.0    57.0   120.0    88.0     7.0     NaN
# 2008-01-04  21    34.0    38.0    94.0   132.0    95.0    30.0     NaN
# 2008-01-05  39    45.0    55.0   127.0   113.0   123.0    44.0     NaN
# ...         ..     ...     ...     ...     ...     ...     ...     ...
# 2024-12-27  31    32.0     NaN   135.0   106.0     NaN    61.0    45.0
# 2024-12-28  43    53.0     NaN   132.0    88.0     NaN    70.0    39.0
# 2024-12-29  45    56.0     NaN   117.0    96.0     NaN    51.0    47.0
# 2024-12-30  42    56.0     NaN    98.0    88.0     NaN    45.0    36.0
# 2024-12-31  41    47.0     NaN     NaN    96.0     NaN    33.0    30.0
#
#             TG 381  TG 854  ...  TG 27902  TG 27904  TG 27905  TG 27906  \
# DATE                        ...
# 2008-01-01   138.0   -30.0  ...       NaN       NaN       NaN       NaN
# 2008-01-02   146.0    -6.0  ...       NaN       NaN       NaN       NaN
# 2008-01-03   135.0   -21.0  ...       NaN       NaN       NaN       NaN
# 2008-01-04   132.0    -8.0  ...       NaN       NaN       NaN       NaN
# 2008-01-05   134.0     7.0  ...       NaN       NaN       NaN       NaN
# ...            ...     ...  ...       ...       ...       ...       ...
# 2024-12-27     NaN     3.0  ...      71.0      18.0     -11.0      72.0
# 2024-12-28     NaN    18.0  ...     106.0      31.0       7.0      74.0
# 2024-12-29     NaN    28.0  ...      95.0      36.0      14.0     102.0
# 2024-12-30     NaN    31.0  ...      82.0      32.0      12.0      85.0
# 2024-12-31     NaN    24.0  ...      62.0      23.0       5.0      67.0
#
#             TG 27907  TG 27908  TG 27909  TG 27910  TG 27911  TG 27912
# DATE
# 2008-01-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2008-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2008-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2008-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2008-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2024-12-27      62.0      39.0      53.0      43.0      76.0      64.0
# 2024-12-28      48.0      40.0      54.0      41.0      71.0      88.0
# 2024-12-29      54.0      41.0      50.0      49.0      79.0      89.0
# 2024-12-30      45.0      30.0      30.0      33.0      69.0      81.0
# 2024-12-31      32.0      17.0      24.0      31.0      62.0      65.0
#
# [6161 rows x 858 columns]

# %%
# Se eliminan todas aquellas estaciones que tienen datos faltantes y se renombra la primera estación con el ID de estación
d=data_unif.dropna(axis=1)
d=d.rename({'TG':'TG '+str(lista_estaciones_italianas[0])},axis=1)
d
# Out:
#             TG 169  TG 11611  TG 17530  TG 17607  TG 17711  TG 17811  \
# DATE
# 2008-01-01      29        14         1       -13         6         6
# 2008-01-02      34        17        -2         0        15        15
# 2008-01-03      17         6         4        -2         2         2
# 2008-01-04      21        38        35        26        10        10
# 2008-01-05      39        48        50        38        27        27
# ...            ...       ...       ...       ...       ...       ...
# 2024-12-27      31        25        27        20        28        28
# 2024-12-28      43        43        39        36        37        37
# 2024-12-29      45        37        32        35        37        37
# 2024-12-30      42        30        29        32        34        34
# 2024-12-31      41        20        14        21        27        27
#
#             TG 27786  TG 27796
# DATE
# 2008-01-01        14        14
# 2008-01-02        17        17
# 2008-01-03         6         6
# 2008-01-04        38        38
# 2008-01-05        48        48
# ...              ...       ...
# 2024-12-27        25        19
# 2024-12-28        43        38
# 2024-12-29        37        36
# 2024-12-30        30        31
# 2024-12-31        20        20
#
# [6161 rows x 8 columns]

# %%
# Estaciones italianas sin valores faltantes
v=[]
for i in d.columns:
    v.append(int(i[3:]))
    
mt=metadata_IT[metadata_IT.STAID.isin(v)]
mt
# Out:
#       STAID                 STANAME  CN        LAT         LON  HGHT
# 130     169                 BOLOGNA  IT  +44:30:00  +011:20:45    53
# 4169  11611         SERMIDE (SP 91)  IT  +45:01:00  +011:17:24    10
# 4286  17530                   BERRA  IT  +44:58:04  +011:53:44     3
# 4330  17607              DIAMANTINA  IT  +44:53:08  +011:30:42     5
# 4398  17711  PADULLE_SALA_BOLOGNESE  IT  +44:37:39  +011:17:26    25
# 4453  17811                SERPIERI  IT  +44:32:53  +011:22:01    28
# 9572  27786      CASTELNOVO BARIANO  IT  +45:01:51  +011:18:09    10
# 9582  27796                TRECENTA  IT  +45:01:18  +011:25:36     9

# %%
#Funcion para transformación de longitudes y latitudes a formato decimal
def dms_a_decimal(dms_str):
    # Quitar el signo y dividir en partes
    signo = -1 if dms_str.startswith("-") else 1
    partes = dms_str.lstrip("+-").split(":")
    grados, minutos, segundos = map(float, partes)
    decimal = signo * (grados + minutos / 60 + segundos / 3600)
    return decimal

# %%
#Transformación de las variables
mt['LAT'] = mt['LAT'].apply(dms_a_decimal)
mt['LON'] = mt['LON'].apply(dms_a_decimal)
mt
# Out:
#       STAID                 STANAME  CN        LAT        LON  HGHT
# 130     169                 BOLOGNA  IT  44.500000  11.345833    53
# 4169  11611         SERMIDE (SP 91)  IT  45.016667  11.290000    10
# 4286  17530                   BERRA  IT  44.967778  11.895556     3
# 4330  17607              DIAMANTINA  IT  44.885556  11.511667     5
# 4398  17711  PADULLE_SALA_BOLOGNESE  IT  44.627500  11.290556    25
# 4453  17811                SERPIERI  IT  44.548056  11.366944    28
# 9572  27786      CASTELNOVO BARIANO  IT  45.030833  11.302500    10
# 9582  27796                TRECENTA  IT  45.021667  11.426667     9

# %%
#Carga de mapas para obtener mapa de Italia
world = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres")) #Carga de países
italia = world[world["name"] == "Italy"] #Mapa de Italia

# %%
#Transformacion de latitudes y longitudes en puntos
estaciones = [Point(xy) for xy in zip(mt['LON'], mt['LAT'])] 
puntos = gpd.GeoDataFrame(mt, geometry=estaciones, crs="EPSG:4326")

# %%
#Gráfica con todas las estaciones
fig, ax = plt.subplots(figsize=(8, 10))
italia.plot(ax=ax, color="white", edgecolor="black")
puntos.plot(ax=ax, color="red", markersize=50)
plt.title("Estaciones Italianas con mediciones de fuerza del viento sin valores nulos")
plt.axis("off")
plt.show()

# %%
#Primer filtrado de estaciones en función del valor truncado de la longitud y latitud
w=[]
ww=[]
for x in zip(mt['LON'],mt['LAT'],mt['STAID']):
    if (math.trunc(x[0]),math.trunc(x[1])) not in w:
        w.append((math.trunc(x[0]),math.trunc(x[1])))
        ww.append(x[2])

mt_it=mt[mt.STAID.isin(ww)]

# %%
#Segundo filtrado de estaciones en función del valor redondeado de la longitud y latitud
w=[]
ww=[]
for x in zip(mt_it['LON'],mt_it['LAT'],mt['STAID']):
    if (round(x[0]),round(x[1])) not in w:
        w.append((round(x[0]),round(x[1])))
        ww.append(x[2])
        
mt_IT=mt_it[mt_it.STAID.isin(ww)]
mt_IT
# Out:
#       STAID          STANAME  CN        LAT        LON  HGHT
# 130     169          BOLOGNA  IT  44.500000  11.345833    53
# 4169  11611  SERMIDE (SP 91)  IT  45.016667  11.290000    10

# %%
#Transformacion de latitudes y longitudes en puntos
estaciones = [Point(xy) for xy in zip(mt_IT['LON'], mt_IT['LAT'])] 
puntos = gpd.GeoDataFrame(mt_IT, geometry=estaciones, crs="EPSG:4326")

# %%
#Gráfica
fig, ax = plt.subplots(figsize=(8, 10))
italia.plot(ax=ax, color="white", edgecolor="black")
puntos.plot(ax=ax, color="red", markersize=50)
plt.title("Estaciones Italianas con mediciones de fuerza del viento sin valores nulos y sin valores de latitud y longitud cercanos")
plt.axis("off")
plt.show()

# %%
#Agrupación de los datos diarios en datos semanales para cada estación
data=d.loc[:,['TG '+str(i) for i in mt_IT.STAID.to_list()]]
data=data.resample('MS').mean()
data
# Out:
#                 TG 169    TG 11611
# DATE
# 2008-01-01   59.935484   53.387097
# 2008-02-01   67.241379   60.517241
# 2008-03-01  106.774194   94.225806
# 2008-04-01  138.633333  133.200000
# 2008-05-01  184.935484  187.096774
# ...                ...         ...
# 2024-08-01  260.709677  261.064516
# 2024-09-01  196.066667  198.600000
# 2024-10-01  161.709677  161.903226
# 2024-11-01   77.400000   75.166667
# 2024-12-01   39.580645   38.741935
#
# [204 rows x 2 columns]

# %%
#Cálculo de la media para cada mes en función del total de estaciones
a=data.mean(axis=1)
a=pd.DataFrame(a).rename({0:'TG'},axis=1)
a
# Out:
#                     TG
# DATE
# 2008-01-01   56.661290
# 2008-02-01   63.879310
# 2008-03-01  100.500000
# 2008-04-01  135.916667
# 2008-05-01  186.016129
# ...                ...
# 2024-08-01  260.887097
# 2024-09-01  197.333333
# 2024-10-01  161.806452
# 2024-11-01   76.283333
# 2024-12-01   39.161290
#
# [204 rows x 1 columns]

# %%
#Exportación de datos mensuales de temperatura en Italia
a.to_csv('temperatura_mensual_ita.csv',index=True,encoding='utf-8')

# %%
#Visualización de datos mensuales
plt.figure(figsize=(13,5))
sns.lineplot(data=a,x=a.index,y=a.TG)
plt.xticks(rotation=90)
plt.show()
