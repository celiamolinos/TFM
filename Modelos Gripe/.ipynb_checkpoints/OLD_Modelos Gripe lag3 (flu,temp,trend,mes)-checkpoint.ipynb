# %%
import warnings 
warnings.filterwarnings('ignore')
from datetime import datetime, timedelta, date
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error,r2_score, mean_absolute_error
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor, GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from tensorflow.keras import Sequential
from tensorflow import keras
from keras.layers import Dropout, Dense, SimpleRNN, LSTM, GRU
from tensorflow.keras.optimizers import Adam
import statistics

# %%
print('Inicio:',datetime.now())
# Out:
# Inicio: 2025-05-16 16:50:55.044260

# %%
# Lectura de datasets 
gripe=pd.read_csv("../Notebooks enfermedades/flu_esp_indexado.csv", sep=",",index_col=0) 
humedad=pd.read_csv("../Notebooks meteorologia/humedad_semanal_esp.csv", sep=",",index_col=0) 
temperatura=pd.read_csv("../Notebooks meteorologia/temperatura_semanal_esp.csv", sep=",",index_col=0) 
viento=pd.read_csv("../Notebooks meteorologia/viento_semanal_esp.csv", sep=",",index_col=0) 
precipitaciones=pd.read_csv("../Notebooks meteorologia/precipitaciones_semanales_esp.csv", sep=",",index_col=0) 
trends=pd.read_csv("../Notebooks google trends/flu_trends.csv", sep=",",index_col=0)

# %%
# Unificación de datasets
gripe_tot=pd.concat([gripe,temperatura,humedad,viento,precipitaciones,trends],axis=1)
gripe_tot.index = pd.to_datetime(gripe_tot.index)
df=gripe_tot.dropna()

# %%
#Incluimos variables númericas para los meses y las semanas
df['mes']=df.index.month
df['semana']=df.index.isocalendar().week
df
# Out:
#             INF_ALL          TG         HU         FG         RR  \
# 2013-09-29      1.0  216.192308  64.974790  27.482993  16.123810
# 2013-10-06      1.0  209.357143  69.941176  28.659864  14.800000
# 2013-10-13      0.0  175.554945  65.201681  26.503401   2.514286
# 2013-10-20      1.0  188.945055  66.605042  25.421769  11.504762
# 2013-10-27      0.0  183.302198  70.630252  29.639456  41.180952
# ...             ...         ...        ...        ...        ...
# 2025-02-23    166.0  127.093407  73.260504  27.136054   7.180952
# 2025-03-02     76.0  107.329670  70.747899  31.666667  35.844444
# 2025-03-09    117.0  122.423077  79.672269  37.414966  71.388889
# 2025-03-16     65.0  101.659341  74.319328  29.843537  46.428571
# 2025-03-23     54.0  119.296703  74.302521  40.870748  49.666667
#
#             gripe_trends  mes  semana
# 2013-09-29            43    9      39
# 2013-10-06            44   10      40
# 2013-10-13            70   10      41
# ...

# %%
df.corr(method='pearson')
# Out:
#                INF_ALL        TG        HU        FG        RR  gripe_trends  \
# INF_ALL       1.000000 -0.498513  0.368581 -0.125674  0.100819      0.551141
# TG           -0.498513  1.000000 -0.709955  0.175184 -0.360496     -0.515073
# HU            0.368581 -0.709955  1.000000 -0.401470  0.589630      0.494141
# FG           -0.125674  0.175184 -0.401470  1.000000  0.121672     -0.240522
# RR            0.100819 -0.360496  0.589630  0.121672  1.000000      0.164511
# gripe_trends  0.551141 -0.515073  0.494141 -0.240522  0.164511      1.000000
# mes          -0.363697  0.295400  0.081417 -0.246429  0.056190     -0.016008
# semana       -0.357238  0.260792  0.112517 -0.274921  0.052971      0.024217
#
#                    mes    semana
# INF_ALL      -0.363697 -0.357238
# TG            0.295400  0.260792
# HU            0.081417  0.112517
# FG           -0.246429 -0.274921
# RR            0.056190  0.052971
# gripe_trends -0.016008  0.024217
# mes           1.000000  0.947200
# ...

# %% [markdown]
# ### Cálculo de la ventana deslizante

# %%
def one_step_forecast(df, window):
    d = df.values
    x = []
    n = len(df)
    idx = df.index[:-window]
    for start in range(n-window):
        end = start + window
        x.append(d[start:end])
    cols = [f'x_{i}' for i in range(1, window+1)]
    x = np.array(x).reshape(n-window, -1)
    y = df.iloc[window:].values
    df_xs = pd.DataFrame(x, columns=cols, index=idx)
    df_y = pd.DataFrame(y.reshape(-1), columns=['y'], index=idx)
    return pd.concat([df_y,df_xs], axis=1).dropna()

# %%
df_inf=one_step_forecast(df.iloc[:,0],4) #ventana deslizante de infectados
df_temp=one_step_forecast(df.iloc[:,1],4).iloc[:,1:].rename({'x_1':'x_1_temp','x_2':'x_2_temp','x_3':'x_3_temp','x_4':'x_4_temp'},axis=1)
df_trend=one_step_forecast(df.iloc[:,5],4).iloc[:,1:].rename({'x_1':'x_1_tre','x_2':'x_2_tre','x_3':'x_3_tre','x_4':'x_4_tre'},axis=1)
df_mes=one_step_forecast(df.iloc[:,6],4).iloc[:,1:].rename({'x_1':'x_1_mes','x_2':'x_2_mes','x_3':'x_3_mes','x_4':'x_4_mes'},axis=1)

# %%
df=pd.concat([df_inf.iloc[:,:2],df_temp.iloc[:,0],df_trend.iloc[:,0],df_mes.iloc[:,0],df_inf.iloc[:,2],
              df_temp.iloc[:,1],df_trend.iloc[:,1],df_mes.iloc[:,1],df_inf.iloc[:,3],df_temp.iloc[:,2],
              df_trend.iloc[:,2],df_mes.iloc[:,2],df_inf.iloc[:,4],df_temp.iloc[:,3],df_trend.iloc[:,3],
              df_mes.iloc[:,3]],axis=1)
df
# Out:
#                 y    x_1    x_1_temp  x_1_tre  x_1_mes    x_2    x_2_temp  \
# 2013-09-29    0.0    1.0  216.192308       43        9    1.0  209.357143
# 2013-10-06    1.0    1.0  209.357143       44       10    0.0  175.554945
# 2013-10-13    0.0    0.0  175.554945       70       10    1.0  188.945055
# 2013-10-20    3.0    1.0  188.945055       54       10    0.0  183.302198
# 2013-10-27    6.0    0.0  183.302198       50       10    1.0  147.148352
# ...           ...    ...         ...      ...      ...    ...         ...
# 2025-01-26  166.0  506.0  116.620879       58        1  419.0   98.769231
# 2025-02-02   76.0  419.0   98.769231       45        2  390.0   90.467033
# 2025-02-09  117.0  390.0   90.467033       41        2  249.0  118.736264
# 2025-02-16   65.0  249.0  118.736264       34        2  166.0  127.093407
# 2025-02-23   54.0  166.0  127.093407       28        2   76.0  107.329670
#
#             x_2_tre  x_2_mes    x_3    x_3_temp  x_3_tre  x_3_mes    x_4  \
# ...

# %% [markdown]
# ### Normalización y separación en test y train

# %%
def split_data(df,test_split=0.1):
    n=int(len(df)*test_split)
    train,test=df[:-n],df[-n:]
    return train, test

# %%
train,test=split_data(df)

# %%
from sklearn.preprocessing import MinMaxScaler
norm=MinMaxScaler()
train_norm=pd.DataFrame(norm.fit_transform(train),index=train.index,columns=train.columns)
test_norm=pd.DataFrame(norm.transform(test),index=test.index,columns=test.columns)

# %%
xtrainN=train_norm.iloc[:,1:]
xtestN=test_norm.iloc[:,1:]
ytrainN=train_norm.iloc[:,0]
ytestN=test_norm.iloc[:,0]
xtrainN.shape
# Out:
# (468, 16)

# %% [markdown]
# ### Regresión lineal

# %%
from sklearn import linear_model
regr=linear_model.LinearRegression()
regr.fit(xtrainN,ytrainN)
ypred=regr.predict(xtestN)
Y_rl=pd.DataFrame(ytestN,index=ytestN.index).rename({'y':'ytest'},axis=1)
Y_rl['ypred']=pd.DataFrame(ypred,index=ytestN.index)
Y_rl
# Out:
#                ytest     ypred
# 2024-03-03  0.014170  0.017365
# 2024-03-10  0.014170  0.031211
# 2024-03-17  0.012146  0.021647
# 2024-03-24  0.006073  0.004449
# 2024-03-31  0.020243  0.021110
# 2024-04-07  0.018219  0.035873
# 2024-04-14  0.008097  0.018983
# 2024-04-21  0.018219  0.009423
# 2024-04-28  0.026316  0.032529
# 2024-05-05  0.006073  0.041385
# 2024-05-12  0.012146 -0.006537
# 2024-05-19  0.010121  0.021552
# 2024-05-26  0.002024  0.005778
# 2024-06-02  0.016194  0.007725
# 2024-06-09  0.006073  0.016766
# 2024-06-16  0.016194 -0.009586
# 2024-06-23  0.018219  0.022111
# 2024-06-30  0.012146  0.004484
# 2024-07-07  0.018219  0.005730
# 2024-07-14  0.016194  0.006373
# 2024-07-21  0.010121  0.003053
# 2024-07-28  0.020243  0.003216
# 2024-08-04  0.028340  0.020558
# 2024-08-11  0.014170  0.012188
# 2024-08-18  0.012146  0.013390
# 2024-08-25  0.012146  0.023975
# 2024-09-01  0.030364  0.022200
# 2024-09-08  0.030364  0.057413
# 2024-09-15  0.044534  0.038846
# ...

# %%
plt.figure(figsize=(12,5))
sns.lineplot(data=Y_rl,x=Y_rl.index,y=Y_rl.ytest,label='ytest')
sns.lineplot(data=Y_rl,x=Y_rl.index,y=Y_rl.ypred,label='ypred')
plt.legend()
plt.xticks(rotation=90)
plt.text(datetime(2024, 3, 1), 0.95*max(Y_rl.ytest), 'La precisión de la predicción es de '+str(r2_score(Y_rl.ytest, Y_rl.ypred)), fontsize=10)
plt.show()

# %% [markdown]
# ### KNNeighbors

# %%
from sklearn.neighbors import KNeighborsRegressor
v=[]
for k in range(1,15):
    knn=KNeighborsRegressor(n_neighbors=k)
    knn.fit(xtrainN,ytrainN)
    ypred=knn.predict(xtestN.values.astype(np.float32))
    v.append(r2_score(ytestN, ypred))

v
# Out:
# [0.791016464060201,
#  0.8156112827478763,
#  0.7981203463849882,
#  0.7943843249007776,
#  0.7936249726946073,
#  0.7847617348645513,
#  0.7756441131703349,
#  0.7551236476565726,
#  0.7488089457343842,
#  0.7380789139250306,
#  0.7275947956078128,
#  0.7201975302373911,
#  0.7128303492710377,
#  0.701078152839542]

# %%
knn=KNeighborsRegressor(n_neighbors=5)
knn.fit(xtrainN,ytrainN)
# Out:
# KNeighborsRegressor()

# %%
ypred_knn=knn.predict(xtestN.values.astype(np.float32))
Y_knn=pd.DataFrame(ytestN,index=ytestN.index).rename({'y':'ytest'},axis=1)
Y_knn['ypred']=pd.DataFrame(ypred_knn,index=ytestN.index)
Y_knn
# Out:
#                ytest     ypred
# 2024-03-03  0.014170  0.011336
# 2024-03-10  0.014170  0.009312
# 2024-03-17  0.012146  0.002834
# 2024-03-24  0.006073  0.002429
# 2024-03-31  0.020243  0.002024
# 2024-04-07  0.018219  0.001215
# 2024-04-14  0.008097  0.000810
# 2024-04-21  0.018219  0.000000
# 2024-04-28  0.026316  0.000000
# 2024-05-05  0.006073  0.000000
# 2024-05-12  0.012146  0.003239
# 2024-05-19  0.010121  0.000405
# 2024-05-26  0.002024  0.001619
# 2024-06-02  0.016194  0.000000
# 2024-06-09  0.006073  0.002429
# 2024-06-16  0.016194  0.004453
# 2024-06-23  0.018219  0.003239
# 2024-06-30  0.012146  0.001215
# 2024-07-07  0.018219  0.000810
# 2024-07-14  0.016194  0.001215
# 2024-07-21  0.010121  0.029555
# 2024-07-28  0.020243  0.008502
# 2024-08-04  0.028340  0.006478
# 2024-08-11  0.014170  0.001215
# 2024-08-18  0.012146  0.000405
# 2024-08-25  0.012146  0.000405
# 2024-09-01  0.030364  0.006073
# 2024-09-08  0.030364  0.000810
# 2024-09-15  0.044534  0.001215
# ...

# %%
plt.figure(figsize=(13,5))
sns.lineplot(data=Y_knn,x=Y_knn.index,y=Y_knn.ytest,label='ytest')
sns.lineplot(data=Y_knn,x=Y_knn.index,y=Y_knn.ypred,label='ypred')
plt.legend()
plt.xticks(rotation=90)
plt.text(datetime(2024, 3, 1), 0.95*max(Y_knn.ytest), 'La precisión de la predicción es de '+str(r2_score(Y_knn.ytest, Y_knn.ypred)), fontsize=10)
plt.show()

# %% [markdown]
# ### Random Forest

# %%
rf=RandomForestRegressor(random_state=0)
rf.fit(xtrainN,ytrainN)
# Out:
# RandomForestRegressor(random_state=0)

# %%
ypred=rf.predict(xtestN.values.astype(np.float32))
Y_rf=pd.DataFrame(ytestN,index=ytestN.index).rename({'y':'ytest'},axis=1)
Y_rf['ypred']=pd.DataFrame(ypred,index=ytestN.index)
Y_rf
# Out:
#                ytest     ypred
# 2024-03-03  0.014170  0.018785
# 2024-03-10  0.014170  0.009109
# 2024-03-17  0.012146  0.008806
# 2024-03-24  0.006073  0.008360
# 2024-03-31  0.020243  0.003482
# 2024-04-07  0.018219  0.012368
# 2024-04-14  0.008097  0.013401
# 2024-04-21  0.018219  0.006478
# 2024-04-28  0.026316  0.007955
# 2024-05-05  0.006073  0.027267
# 2024-05-12  0.012146  0.019049
# 2024-05-19  0.010121  0.006660
# 2024-05-26  0.002024  0.011721
# 2024-06-02  0.016194  0.004595
# 2024-06-09  0.006073  0.010061
# 2024-06-16  0.016194  0.011599
# 2024-06-23  0.018219  0.010000
# 2024-06-30  0.012146  0.013603
# 2024-07-07  0.018219  0.017085
# 2024-07-14  0.016194  0.016012
# 2024-07-21  0.010121  0.017976
# 2024-07-28  0.020243  0.017045
# 2024-08-04  0.028340  0.017105
# 2024-08-11  0.014170  0.033745
# 2024-08-18  0.012146  0.032227
# 2024-08-25  0.012146  0.017530
# 2024-09-01  0.030364  0.017429
# 2024-09-08  0.030364  0.033806
# 2024-09-15  0.044534  0.046093
# ...

# %%
plt.figure(figsize=(13,5))
sns.lineplot(data=Y_rf,x=Y_rf.index,y=Y_rf.ytest,label='ytest')
sns.lineplot(data=Y_rf,x=Y_rf.index,y=Y_rf.ypred,label='ypred')
plt.legend()
plt.xticks(rotation=90)
plt.text(datetime(2024, 3, 1), 0.95*max(Y_rf.ytest), 'La precisión de la predicción es de '+str(r2_score(Y_rf.ytest, Y_rf.ypred)), fontsize=10)
plt.show()

# %% [markdown]
# ### Gradient Boosting

# %%
gbr=GradientBoostingRegressor(random_state=0)
gbr.fit(xtrainN,ytrainN)
ypred_gbr=gbr.predict(xtestN.values.astype(np.float32))
Y_gbr=pd.DataFrame(ytestN,index=ytestN.index).rename({'y':'ytest'},axis=1)
Y_gbr['ypred']=pd.DataFrame(ypred_gbr,index=ytestN.index)
Y_gbr
# Out:
#                ytest     ypred
# 2024-03-03  0.014170  0.022182
# 2024-03-10  0.014170  0.002488
# 2024-03-17  0.012146  0.008793
# 2024-03-24  0.006073  0.002046
# 2024-03-31  0.020243  0.006803
# 2024-04-07  0.018219  0.007292
# 2024-04-14  0.008097  0.012065
# 2024-04-21  0.018219  0.002046
# 2024-04-28  0.026316  0.005631
# 2024-05-05  0.006073  0.015642
# 2024-05-12  0.012146  0.023191
# 2024-05-19  0.010121  0.002110
# 2024-05-26  0.002024  0.006803
# 2024-06-02  0.016194  0.006803
# 2024-06-09  0.006073  0.000765
# 2024-06-16  0.016194  0.006803
# 2024-06-23  0.018219  0.002110
# 2024-06-30  0.012146  0.008645
# 2024-07-07  0.018219  0.011674
# 2024-07-14  0.016194  0.014330
# 2024-07-21  0.010121  0.020599
# 2024-07-28  0.020243  0.023301
# 2024-08-04  0.028340  0.013938
# 2024-08-11  0.014170  0.020866
# 2024-08-18  0.012146  0.028257
# 2024-08-25  0.012146  0.011869
# 2024-09-01  0.030364  0.011869
# 2024-09-08  0.030364  0.017606
# 2024-09-15  0.044534  0.033994
# ...

# %%
plt.figure(figsize=(13,5))
sns.lineplot(data=Y_gbr,x=Y_gbr.index,y=Y_gbr.ytest,label='ytest')
sns.lineplot(data=Y_gbr,x=Y_gbr.index,y=Y_gbr.ypred,label='ypred')
plt.legend()
plt.xticks(rotation=90)
plt.text(datetime(2024, 3, 1), 0.95*max(Y_gbr.ytest), 'La precisión de la predicción es de '+str(r2_score(Y_gbr.ytest, Y_gbr.ypred)), fontsize=10)
plt.show()

# %% [markdown]
# ### Validación

# %%
xtrainN,xvalN=split_data(xtrainN)
ytrainN,yvalN=split_data(ytrainN)

# %% [markdown]
# ### RNA (Adam learning_rate=0.005)

# %%
Y_RNA=pd.DataFrame(ytestN,index=ytestN.index).rename({'y':'ytest'},axis=1)
for i in range(4):
    RNA=Sequential()
    RNA.add(Dense(units=32,kernel_initializer='uniform',activation='relu',input_dim=(len(xtrainN.columns))))
    RNA.add(Dropout(0.1))
    RNA.add(Dense(units=32,kernel_initializer='uniform',activation='relu'))
    RNA.add(Dropout(0.1))
    RNA.add(Dense(units=32,kernel_initializer='uniform',activation='relu'))
    RNA.add(Dropout(0.1))
    RNA.add(Dense(1))
    RNA.compile(optimizer=Adam(learning_rate=0.005),loss='mean_squared_error')
    RNA.fit(xtrainN,ytrainN,batch_size=32,epochs=500,shuffle=False,validation_data=(xvalN,yvalN))
    ypred_RNA=RNA.predict(xtestN)
    Y_RNA['ypred_'+str(i)]=pd.DataFrame(ypred_RNA,index=ytestN.index)
    
Y_RNA
# Out:
# Epoch 1/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0540 - val_loss: 0.0334
# Epoch 2/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0319 - val_loss: 0.0247
# Epoch 3/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0197 - val_loss: 0.0212
# Epoch 4/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0149 - val_loss: 0.0107
# Epoch 5/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0119 - val_loss: 0.0134
# Epoch 6/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0132 - val_loss: 0.0118
# Epoch 7/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0079 - val_loss: 0.0085
# Epoch 8/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0067 - val_loss: 0.0093
# Epoch 9/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0092 - val_loss: 0.0081
# Epoch 10/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 11/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0090 - val_loss: 0.0083
# Epoch 12/500
# ...

# %%
vvv=[]
kkk=[]
aaa=[]
for i in range(4):
    vvv.append(r2_score(Y_RNA.iloc[:,0], Y_RNA.iloc[:,i+1]))
    aaa.append(mean_squared_error(Y_RNA.iloc[:,0], Y_RNA.iloc[:,i+1]))
    kkk.append(mean_absolute_error(Y_RNA.iloc[:,0], Y_RNA.iloc[:,i+1]))

print(vvv)
print(kkk)
print(aaa)
# Out:
# [0.9184160919771355, 0.9262767282445121, 0.9393761625044321, 0.927070157285488]
# [0.05036534573485462, 0.04750408541852895, 0.039894335003809296, 0.04113047392187597]
# [0.008211321424835393, 0.007420157915273456, 0.0061017157396233415, 0.007340300244304492]

# %% [markdown]
# ### RNA (Adam learning_rate=0.003)

# %%
Y_rna=pd.DataFrame(ytestN,index=ytestN.index).rename({'y':'ytest'},axis=1)
for i in range(4):
    rna=Sequential()
    rna.add(Dense(units=32,kernel_initializer='uniform',activation='relu',input_dim=(len(xtrainN.columns))))
    rna.add(Dropout(0.1))
    rna.add(Dense(units=32,kernel_initializer='uniform',activation='relu'))
    rna.add(Dropout(0.1))
    rna.add(Dense(units=32,kernel_initializer='uniform',activation='relu'))
    rna.add(Dropout(0.1))
    rna.add(Dense(1))
    rna.compile(optimizer=Adam(learning_rate=0.003),loss='mean_squared_error')
    rna.fit(xtrainN,ytrainN,batch_size=32,epochs=500,shuffle=False,validation_data=(xvalN,yvalN))
    ypred_rna=rna.predict(xtestN)
    Y_rna['ypred_'+str(i)]=pd.DataFrame(ypred_rna,index=ytestN.index)
    
Y_rna
# Out:
# Epoch 1/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0544 - val_loss: 0.0364
# Epoch 2/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0392 - val_loss: 0.0232
# Epoch 3/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0212 - val_loss: 0.0202
# Epoch 4/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0170 - val_loss: 0.0142
# Epoch 5/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0093 - val_loss: 0.0094
# Epoch 6/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0089 - val_loss: 0.0089
# Epoch 7/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0093 - val_loss: 0.0085
# Epoch 8/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074 - val_loss: 0.0062
# Epoch 9/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0100 - val_loss: 0.0071
# Epoch 10/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0087 - val_loss: 0.0081
# Epoch 11/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0095 - val_loss: 0.0065
# Epoch 12/500
# ...

# %%
a=[]
k=[]
v=[]
for i in range(4):
    v.append(r2_score(Y_rna.iloc[:,0], Y_rna.iloc[:,i+1]))
    a.append(mean_squared_error(Y_rna.iloc[:,0], Y_rna.iloc[:,i+1]))
    k.append(mean_absolute_error(Y_rna.iloc[:,0], Y_rna.iloc[:,i+1]))

print(v)
print(k)
print(a)
# Out:
# [0.929873496787708, 0.9505555953103066, 0.9148915223517669, 0.9148956146366326]
# [0.04519112736850453, 0.03991506156914471, 0.05233410040108932, 0.05427793641902427]
# [0.007058147522358205, 0.004976519382387578, 0.00856606508421001, 0.008565653200700027]

# %% [markdown]
# ### RNA (Adam learning_rate=0.001)

# %%
Y_rna_=pd.DataFrame(ytestN,index=ytestN.index).rename({'y':'ytest'},axis=1)
for i in range(4):
    rna_=Sequential()
    rna_.add(Dense(units=32,kernel_initializer='uniform',activation='relu',input_dim=(len(xtrainN.columns))))
    rna_.add(Dropout(0.1))
    rna_.add(Dense(units=32,kernel_initializer='uniform',activation='relu'))
    rna_.add(Dropout(0.1))
    rna_.add(Dense(units=32,kernel_initializer='uniform',activation='relu'))
    rna_.add(Dropout(0.1))
    rna_.add(Dense(1))
    rna_.compile(optimizer='adam',loss='mean_squared_error')
    rna_.fit(xtrainN,ytrainN,batch_size=32,epochs=500,shuffle=False,validation_data=(xvalN,yvalN))
    ypred_rna_=rna_.predict(xtestN)
    Y_rna_['ypred_'+str(i)]=pd.DataFrame(ypred_rna_,index=ytestN.index)
    
Y_rna_
# Out:
# Epoch 1/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0579 - val_loss: 0.0430
# Epoch 2/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0481 - val_loss: 0.0362
# Epoch 3/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0414 - val_loss: 0.0298
# Epoch 4/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0334 - val_loss: 0.0223
# Epoch 5/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0239 - val_loss: 0.0185
# Epoch 6/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0171 - val_loss: 0.0182
# Epoch 7/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0153 - val_loss: 0.0160
# Epoch 8/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0128 - val_loss: 0.0132
# Epoch 9/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0113 - val_loss: 0.0117
# Epoch 10/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0085 - val_loss: 0.0106
# Epoch 11/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0081 - val_loss: 0.0101
# Epoch 12/500
# ...

# %%
vv=[]
kk=[]
aa=[]
for i in range(4):
    vv.append(r2_score(Y_rna_.iloc[:,0], Y_rna_.iloc[:,i+1]))
    kk.append(mean_absolute_error(Y_rna_.iloc[:,0], Y_rna_.iloc[:,i+1]))
    aa.append(mean_squared_error(Y_rna_.iloc[:,0], Y_rna_.iloc[:,i+1]))

print(vv)
print(kk)
print(aa)
# Out:
# [0.8998737639090817, 0.9182200246985449, 0.9247980419421304, 0.8907055682902458]
# [0.053088933012640546, 0.049663666598191374, 0.049521906058107065, 0.05643973069216758]
# [0.010077584262953734, 0.008231055358700742, 0.007568985898752185, 0.011000352035869559]

# %% [markdown]
# ### RNN Adam(learning_rate=0.003)

# %%
Y_rnn=pd.DataFrame(ytestN,index=ytestN.index).rename({'y':'ytest'},axis=1)
for i in range(4):
    rnn=Sequential()
    rnn.add(SimpleRNN(32, activation='relu', input_shape=(len(xtrainN.columns), 1)))
    rnn.add(Dropout(0.1))
    rnn.add(Dense(1))
    rnn.compile(optimizer=Adam(learning_rate=0.003),loss='mse')
    rnn.fit(xtrainN,ytrainN,batch_size=32,epochs=500,shuffle=False,validation_data=(xvalN,yvalN))
    ypred_rnn=rnn.predict(xtestN)
    Y_rnn['ypred_'+str(i)]=pd.DataFrame(ypred_rnn,index=ytestN.index)
    
Y_rnn
# Out:
# Epoch 1/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.1203 - val_loss: 0.0671
# Epoch 2/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0455 - val_loss: 0.0448
# Epoch 3/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0300 - val_loss: 0.0365
# Epoch 4/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0220 - val_loss: 0.0266
# Epoch 5/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0180 - val_loss: 0.0215
# Epoch 6/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0189 - val_loss: 0.0196
# Epoch 7/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0142 - val_loss: 0.0159
# Epoch 8/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0125 - val_loss: 0.0140
# Epoch 9/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0108 - val_loss: 0.0130
# Epoch 10/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0093 - val_loss: 0.0115
# Epoch 11/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0097 - val_loss: 0.0109
# Epoch 12/500
# ...

# %%
w=[]
l=[]
b=[]
for i in range(4):
    w.append(r2_score(Y_rnn.iloc[:,0], Y_rnn.iloc[:,i+1]))
    b.append(mean_squared_error(Y_rnn.iloc[:,0], Y_rnn.iloc[:,i+1]))
    l.append(mean_absolute_error(Y_rnn.iloc[:,0], Y_rnn.iloc[:,i+1]))

print(w)
print(l)
print(b)
# Out:
# [0.877880829111217, 0.8362693676497109, 0.8977862867001287, 0.8433494047452741]
# [0.055659990352516106, 0.06179234218310619, 0.05338368763246874, 0.06952061185109183]
# [0.012291146484686257, 0.016479289628329456, 0.010287686313040946, 0.015766692478961054]

# %% [markdown]
# ### RNN Adam(learning_rate=0.001)

# %%
Y_rnn_=pd.DataFrame(ytestN,index=ytestN.index).rename({'y':'ytest'},axis=1)
for i in range(4):
    rnn_=Sequential()
    rnn_.add(SimpleRNN(32, activation='relu', input_shape=(len(xtrainN.columns), 1)))
    rnn_.add(Dropout(0.1))
    rnn_.add(Dense(1))
    rnn_.compile(optimizer='Adam',loss='mse')
    rnn_.fit(xtrainN,ytrainN,batch_size=32,epochs=500,shuffle=False,validation_data=(xvalN,yvalN))
    ypred_rnn_=rnn_.predict(xtestN)
    Y_rnn_['ypred_'+str(i)]=pd.DataFrame(ypred_rnn_,index=ytestN.index)
    
Y_rnn_
# Out:
# Epoch 1/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0663 - val_loss: 0.0381
# Epoch 2/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0520 - val_loss: 0.0339
# Epoch 3/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0473 - val_loss: 0.0316
# Epoch 4/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0430 - val_loss: 0.0291
# Epoch 5/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0373 - val_loss: 0.0262
# Epoch 6/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0326 - val_loss: 0.0229
# Epoch 7/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0272 - val_loss: 0.0200
# Epoch 8/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0230 - val_loss: 0.0184
# Epoch 9/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0208 - val_loss: 0.0167
# Epoch 10/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0191 - val_loss: 0.0155
# Epoch 11/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0168 - val_loss: 0.0130
# Epoch 12/500
# ...

# %%
ww=[]
ll=[]
bb=[]
for i in range(4):
    ww.append(r2_score(Y_rnn_.iloc[:,0], Y_rnn_.iloc[:,i+1]))
    ll.append(mean_absolute_error(Y_rnn_.iloc[:,0], Y_rnn_.iloc[:,i+1]))
    bb.append(mean_squared_error(Y_rnn_.iloc[:,0], Y_rnn_.iloc[:,i+1]))

print(bb)
print(ll)
print(ww)
# Out:
# [0.012105798544785653, 0.012197382182786678, 0.01253462690456653, 0.00915205419207822]
# [0.05554428644743999, 0.058890110096679285, 0.0641747988168497, 0.0454923159766818]
# [0.8797223608816508, 0.8788124280325389, 0.8754617197921248, 0.9090694044482921]

# %% [markdown]
# ### RNN Adam(learning_rate=0.005)

# %%
Y_RNN=pd.DataFrame(ytestN,index=ytestN.index).rename({'y':'ytest'},axis=1)
for i in range(4):
    RNN=Sequential()
    RNN.add(SimpleRNN(32, activation='relu', input_shape=(len(xtrainN.columns), 1)))
    RNN.add(Dropout(0.1))
    RNN.add(Dense(1))
    RNN.compile(optimizer='Adam',loss='mse')
    RNN.fit(xtrainN,ytrainN,batch_size=32,epochs=500,shuffle=False,validation_data=(xvalN,yvalN))
    ypred_RNN=RNN.predict(xtestN)
    Y_RNN['ypred_'+str(i)]=pd.DataFrame(ypred_RNN,index=ytestN.index)
    
Y_RNN
# Out:
# Epoch 1/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0534 - val_loss: 0.0399
# Epoch 2/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0343 - val_loss: 0.0279
# Epoch 3/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0199 - val_loss: 0.0223
# Epoch 4/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0176 - val_loss: 0.0190
# Epoch 5/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0157 - val_loss: 0.0167
# Epoch 6/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0153 - val_loss: 0.0175
# Epoch 7/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0191 - val_loss: 0.0148
# Epoch 8/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0122 - val_loss: 0.0118
# Epoch 9/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0140 - val_loss: 0.0122
# Epoch 10/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0110 - val_loss: 0.0096
# Epoch 11/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0118 - val_loss: 0.0098
# Epoch 12/500
# ...

# %%
www=[]
lll=[]
bbb=[]
for i in range(4):
    www.append(r2_score(Y_RNN.iloc[:,0], Y_RNN.iloc[:,i+1]))
    bbb.append(mean_squared_error(Y_RNN.iloc[:,0], Y_RNN.iloc[:,i+1]))
    lll.append(mean_absolute_error(Y_RNN.iloc[:,0], Y_RNN.iloc[:,i+1]))

print(www)
print(lll)
print(bbb)
# Out:
# [0.9008270394548167, 0.8739511905897664, 0.9014636986431708, 0.8563840984139328]
# [0.048409674393795656, 0.053843685092270485, 0.0559907788980714, 0.06385667145232504]
# [0.009981638235089126, 0.0126866598373195, 0.009917559259708525, 0.014454766365325663]

# %% [markdown]
# ### LSTM Adam(learning_rate=0.001)

# %%
Y_lstm_=pd.DataFrame(ytestN,index=ytestN.index).rename({'INF_ALL':'ytest'},axis=1)
for i in range(4):
    lstm_ = Sequential()
    lstm_.add(LSTM(64, activation='relu', input_shape=(len(xtrainN.columns), 1)))
    lstm_.add(Dropout(0.1))
    lstm_.add(Dense(1))
    lstm_.compile(optimizer='adam', loss='mse')
    lstm_.fit(xtrainN, ytrainN, batch_size=32, epochs=500, verbose=1,shuffle=False,validation_data=(xvalN,yvalN))
    ypred_lstm_=lstm_.predict(xtestN)
    Y_lstm_['ypred_'+str(i)]=pd.DataFrame(ypred_lstm_,index=ytestN.index)

Y_lstm_
# Out:
# Epoch 1/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0626 - val_loss: 0.0385
# Epoch 2/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0459 - val_loss: 0.0357
# Epoch 3/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0441 - val_loss: 0.0354
# Epoch 4/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0442 - val_loss: 0.0352
# Epoch 5/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0433 - val_loss: 0.0342
# Epoch 6/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0427 - val_loss: 0.0332
# Epoch 7/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0405 - val_loss: 0.0321
# Epoch 8/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0399 - val_loss: 0.0309
# Epoch 9/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0373 - val_loss: 0.0296
# Epoch 10/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0367 - val_loss: 0.0284
# Epoch 11/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0353 - val_loss: 0.0266
# Epoch 12/500
# ...

# %%
uu=[]
mm=[]
cc=[]
for i in range(4):
    uu.append(r2_score(Y_lstm_.iloc[:,0], Y_lstm_.iloc[:,i+1]))
    cc.append(mean_squared_error(Y_lstm_.iloc[:,0], Y_lstm_.iloc[:,i+1]))
    mm.append(mean_absolute_error(Y_lstm_.iloc[:,0], Y_lstm_.iloc[:,i+1]))

print(uu)
print(mm)
print(cc)
# Out:
# [0.874331064611161, 0.9078420043258028, 0.8697812665786495, 0.84685150168503]
# [0.058380106849348204, 0.0588298521290453, 0.06520789928555347, 0.0600783837752806]
# [0.01264842597765025, 0.009275590526226589, 0.013106357633149825, 0.015414210668146001]

# %% [markdown]
# ### LSTM Adam(learning_rate=0.003)

# %%
Y_lstm=pd.DataFrame(ytestN,index=ytestN.index).rename({'y':'ytest'},axis=1)
for i in range(4):
    lstm = Sequential()
    lstm.add(LSTM(64, activation='relu', input_shape=(len(xtrainN.columns), 1)))
    lstm.add(Dropout(0.1))
    lstm.add(Dense(1))
    lstm.compile(optimizer=Adam(learning_rate=0.003), loss='mse')
    lstm.fit(xtrainN, ytrainN, batch_size=32, epochs=500, verbose=1,shuffle=False,validation_data=(xvalN,yvalN))
    ypred_lstm=lstm.predict(xtestN)
    Y_lstm['ypred_'+str(i)]=pd.DataFrame(ypred_lstm,index=ytestN.index)

Y_lstm
# Out:
# Epoch 1/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0529 - val_loss: 0.0352
# Epoch 2/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0460 - val_loss: 0.0352
# Epoch 3/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0439 - val_loss: 0.0335
# Epoch 4/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0430 - val_loss: 0.0330
# Epoch 5/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0405 - val_loss: 0.0313
# Epoch 6/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0388 - val_loss: 0.0318
# Epoch 7/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0365 - val_loss: 0.0320
# Epoch 8/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0364 - val_loss: 0.0274
# Epoch 9/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0327 - val_loss: 0.0299
# Epoch 10/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0317 - val_loss: 0.0299
# Epoch 11/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0291 - val_loss: 0.0266
# Epoch 12/500
# ...

# %%
u=[]
m=[]
c=[]
for i in range(4):
    u.append(r2_score(Y_lstm.iloc[:,0], Y_lstm.iloc[:,i+1]))
    c.append(mean_squared_error(Y_lstm.iloc[:,0], Y_lstm.iloc[:,i+1]))
    m.append(mean_absolute_error(Y_lstm.iloc[:,0], Y_lstm.iloc[:,i+1]))

print(u)
print(m)
print(c)
# Out:
# [0.7442754555407325, 0.840718948302839, 0.7996528198811543, 0.8427245644180393]
# [0.08499684592014875, 0.07270853302700545, 0.07114390915938996, 0.06404031754092278]
# [0.0257383653426624, 0.01603144473055471, 0.020164700764937322, 0.01582958190029995]

# %% [markdown]
# ### LSTM Adam(learning_rate=0.005)

# %%
Y_Lstm=pd.DataFrame(ytestN,index=ytestN.index).rename({'y':'ytest'},axis=1)
for i in range(4):
    Lstm = Sequential()
    Lstm.add(LSTM(64, activation='relu', input_shape=(len(xtrainN.columns), 1)))
    Lstm.add(Dropout(0.1))
    Lstm.add(Dense(1))
    Lstm.compile(optimizer=Adam(learning_rate=0.005), loss='mse')
    Lstm.fit(xtrainN, ytrainN, batch_size=32, epochs=500, verbose=1,shuffle=False,validation_data=(xvalN,yvalN))
    ypred_Lstm=Lstm.predict(xtestN)
    Y_Lstm['ypred_'+str(i)]=pd.DataFrame(ypred_Lstm,index=ytestN.index)

Y_Lstm
# Out:
# Epoch 1/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0535 - val_loss: 0.0449
# Epoch 2/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0511 - val_loss: 0.0352
# Epoch 3/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0460 - val_loss: 0.0354
# Epoch 4/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0447 - val_loss: 0.0350
# Epoch 5/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0430 - val_loss: 0.0363
# Epoch 6/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0428 - val_loss: 0.0347
# Epoch 7/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0410 - val_loss: 0.0312
# Epoch 8/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0366 - val_loss: 0.0392
# Epoch 9/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0401 - val_loss: 0.0288
# Epoch 10/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0326 - val_loss: 0.0432
# Epoch 11/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0364 - val_loss: 0.0332
# Epoch 12/500
# ...

# %%
uuu=[]
mmm=[]
ccc=[]
for i in range(4):
    uuu.append(r2_score(Y_Lstm.iloc[:,0], Y_Lstm.iloc[:,i+1]))
    ccc.append(mean_squared_error(Y_Lstm.iloc[:,0], Y_Lstm.iloc[:,i+1]))
    mmm.append(mean_absolute_error(Y_Lstm.iloc[:,0], Y_Lstm.iloc[:,i+1]))

print(uuu)
print(mmm)
print(ccc)
# Out:
# [0.8411868017193144, 0.8740509200164766, 0.8512340191973936, 0.8346657622223752]
# [0.06506847418590624, 0.06247606717963125, 0.05955614399948607, 0.06766919968174077]
# [0.01598435585144255, 0.01267662219143961, 0.014973115594177458, 0.0166406905702747]

# %% [markdown]
# ### GRU (Adam learning_rate=0.005)

# %%
Y_Gru=pd.DataFrame(ytestN,index=ytestN.index).rename({'y':'ytest'},axis=1)
for i in range(4):
    Gru = Sequential()
    Gru.add(GRU(64 , activation='relu', input_shape=(len(xtrainN.columns), 1)))
    Gru.add(Dropout(0.1))
    Gru.add(Dense(1))
    Gru.compile(optimizer=Adam(learning_rate=0.005), loss='mse')
    Gru.fit(xtrainN, ytrainN, batch_size=32, epochs=500, verbose=1,shuffle=False,validation_data=(xvalN,yvalN))
    ypred_Gru=Gru.predict(xtestN)
    Y_Gru['ypred_'+str(i)]=pd.DataFrame(ypred_Gru,index=ytestN.index)

Y_Gru
# Out:
# Epoch 1/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0611 - val_loss: 0.0411
# Epoch 2/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0468 - val_loss: 0.0397
# Epoch 3/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0412 - val_loss: 0.0389
# Epoch 4/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0352 - val_loss: 0.0362
# Epoch 5/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0278 - val_loss: 0.0345
# Epoch 6/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0206 - val_loss: 0.0246
# Epoch 7/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0164 - val_loss: 0.0244
# Epoch 8/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0152 - val_loss: 0.0240
# Epoch 9/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0154 - val_loss: 0.0241
# Epoch 10/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0142 - val_loss: 0.0244
# Epoch 11/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0148 - val_loss: 0.0224
# Epoch 12/500
# ...

# %%
yyy=[]
nnn=[]
ddd=[]
for i in range(4):
    yyy.append(r2_score(Y_Gru.iloc[:,0], Y_Gru.iloc[:,i+1]))
    nnn.append(mean_absolute_error(Y_Gru.iloc[:,0], Y_Gru.iloc[:,i+1]))
    ddd.append(mean_squared_error(Y_Gru.iloc[:,0], Y_Gru.iloc[:,i+1]))

print(yyy)
print(nnn)
print(ddd)
# Out:
# [0.8200584912127439, 0.8764361555336646, 0.8312463793741205, 0.8342028710769677]
# [0.07878491954387222, 0.06948223146538902, 0.07976949738177036, 0.08185075651923886]
# [0.01811089468658335, 0.012436551128650181, 0.01698484730806813, 0.016687280002820458]

# %% [markdown]
# ### GRU (Adam learning_rate=0.003)

# %%
Y_gru=pd.DataFrame(ytestN,index=ytestN.index).rename({'y':'ytest'},axis=1)
for i in range(4):
    gru = Sequential()
    gru.add(GRU(64, activation='relu', input_shape=(len(xtrainN.columns), 1)))
    gru.add(Dropout(0.1))
    gru.add(Dense(1))
    gru.compile(optimizer=Adam(learning_rate=0.003), loss='mse')
    gru.fit(xtrainN, ytrainN, batch_size=32, epochs=500, verbose=1,shuffle=False,validation_data=(xvalN,yvalN))
    ypred_gru=gru.predict(xtestN)
    Y_gru['ypred_'+str(i)]=pd.DataFrame(ypred_gru,index=ytestN.index)

Y_gru
# Out:
# Epoch 1/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 0.0527 - val_loss: 0.0381
# Epoch 2/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0430 - val_loss: 0.0387
# Epoch 3/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0398 - val_loss: 0.0379
# Epoch 4/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0348 - val_loss: 0.0368
# Epoch 5/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0297 - val_loss: 0.0343
# Epoch 6/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0222 - val_loss: 0.0294
# Epoch 7/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0176 - val_loss: 0.0234
# Epoch 8/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0142 - val_loss: 0.0233
# Epoch 9/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0137 - val_loss: 0.0254
# Epoch 10/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0153 - val_loss: 0.0250
# Epoch 11/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0149 - val_loss: 0.0190
# ...

# %%
y=[]
n=[]
d=[]
for i in range(4):
    y.append(r2_score(Y_gru.iloc[:,0], Y_gru.iloc[:,i+1]))
    d.append(mean_squared_error(Y_gru.iloc[:,0], Y_gru.iloc[:,i+1]))
    n.append(mean_absolute_error(Y_gru.iloc[:,0], Y_gru.iloc[:,i+1]))

print(y)
print(n)
print(d)
# Out:
# [0.8961030310627616, 0.8597555917283107, 0.849980225291089, 0.8597341491245658]
# [0.05772173353878371, 0.06418728979730214, 0.06667933213007957, 0.06856653223251294]
# [0.010457103952052729, 0.014115429651052528, 0.01509930843066529, 0.01411758782312103]

# %% [markdown]
# ### GRU (Adam learning_rate=0.001)

# %%
Y_gru_=pd.DataFrame(ytestN,index=ytestN.index).rename({'y':'ytest'},axis=1)
for i in range(4):
    gru_ = Sequential()
    gru_.add(GRU(64, activation='relu', input_shape=(len(xtrainN.columns), 1)))
    gru_.add(Dropout(0.1))
    gru_.add(Dense(1))
    gru_.compile(optimizer='adam', loss='mse')
    gru_.fit(xtrainN, ytrainN, batch_size=32, epochs=500, verbose=1,shuffle=False,validation_data=(xvalN,yvalN))
    ypred_gru_=gru_.predict(xtestN)
    Y_gru_['ypred_'+str(i)]=pd.DataFrame(ypred_gru_,index=ytestN.index)

Y_gru_
# Out:
# Epoch 1/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0545 - val_loss: 0.0375
# Epoch 2/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0485 - val_loss: 0.0370
# Epoch 3/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0452 - val_loss: 0.0374
# Epoch 4/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0434 - val_loss: 0.0375
# Epoch 5/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0425 - val_loss: 0.0371
# Epoch 6/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0413 - val_loss: 0.0368
# Epoch 7/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0391 - val_loss: 0.0365
# Epoch 8/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0370 - val_loss: 0.0358
# Epoch 9/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0364 - val_loss: 0.0353
# Epoch 10/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0334 - val_loss: 0.0343
# Epoch 11/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0310 - val_loss: 0.0334
# Epoch 12/500
# ...

# %%
yy=[]
nn=[]
dd=[]
for i in range(4):
    yy.append(r2_score(Y_gru_.iloc[:,0], Y_gru_.iloc[:,i+1]))
    dd.append(mean_squared_error(Y_gru_.iloc[:,0], Y_gru_.iloc[:,i+1]))
    nn.append(mean_absolute_error(Y_gru_.iloc[:,0], Y_gru_.iloc[:,i+1]))

print(yy)
print(nn)
print(dd)
# Out:
# [0.8781937293337007, 0.7816523941947326, 0.8127733475921193, 0.8678460047180254]
# [0.06130349401115433, 0.08335389499588801, 0.06651921110194059, 0.06137298121807644]
# [0.012259653456673977, 0.02197642178538228, 0.018844135559014628, 0.013301139392983595]

# %% [markdown]
# ### 3-LSTM (Adam learning_rate=0.005)

# %%
Y_rnn_LSTM=pd.DataFrame(ytestN,index=ytestN.index).rename({'y':'ytest'},axis=1)
for i in range(4):
    rnn_LSTM3 = Sequential()
    rnn_LSTM3.add(LSTM(64, input_shape=(len(xtrainN.columns), 1),return_sequences=True))
    rnn_LSTM3.add(Dropout(0.1))
    rnn_LSTM3.add(LSTM(64,return_sequences=True))
    rnn_LSTM3.add(Dropout(0.1))
    rnn_LSTM3.add(LSTM(64))
    rnn_LSTM3.add(Dense(1))
    rnn_LSTM3.compile(optimizer=Adam(learning_rate=0.005), loss='mse')
    rnn_LSTM3.fit(xtrainN, ytrainN, batch_size=32, epochs=500, verbose=1,shuffle=False,validation_data=(xvalN,yvalN))
    ypred_rnn_LSTM=rnn_LSTM3.predict(xtestN)
    Y_rnn_LSTM['ypred_'+str(i)]=pd.DataFrame(ypred_rnn_LSTM,index=ytestN.index)

Y_rnn_LSTM
# Out:
# Epoch 1/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - loss: 0.0612 - val_loss: 0.0398
# Epoch 2/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0473 - val_loss: 0.0384
# Epoch 3/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0463 - val_loss: 0.0360
# Epoch 4/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0449 - val_loss: 0.0329
# Epoch 5/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0435 - val_loss: 0.0351
# Epoch 6/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0452 - val_loss: 0.0333
# Epoch 7/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0431 - val_loss: 0.0347
# Epoch 8/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0455 - val_loss: 0.0309
# Epoch 9/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0418 - val_loss: 0.0379
# Epoch 10/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0474 - val_loss: 0.0359
# Epoch 11/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0450 - val_loss: 0.0328
# ...

# %%
zzz=[]
ooo=[]
eee=[]
for i in range(4):
    zzz.append(r2_score(Y_rnn_LSTM.iloc[:,0], Y_rnn_LSTM.iloc[:,i+1]))
    eee.append(mean_squared_error(Y_rnn_LSTM.iloc[:,0], Y_rnn_LSTM.iloc[:,i+1]))
    ooo.append(mean_absolute_error(Y_rnn_LSTM.iloc[:,0], Y_rnn_LSTM.iloc[:,i+1]))

print(zzz)
print(ooo)
print(eee)
# Out:
# [0.8129086788242895, 0.7856844717855415, 0.8420438254713473, 0.7839319800157283]
# [0.06863334625077672, 0.06820999923890456, 0.06311005108552684, 0.08935777138372199]
# [0.018830514634581127, 0.021570598064621953, 0.015898097449912087, 0.021746984236418014]

# %% [markdown]
# ### 3-LSTM (Adam learning_rate=0.003)

# %%
Y_rnn_lstm=pd.DataFrame(ytestN,index=ytestN.index).rename({'y':'ytest'},axis=1)
for i in range(4):
    rnn_lstm3 = Sequential()
    rnn_lstm3.add(LSTM(64, input_shape=(len(xtrainN.columns), 1),return_sequences=True))
    rnn_lstm3.add(Dropout(0.1))
    rnn_lstm3.add(LSTM(64,return_sequences=True))
    rnn_lstm3.add(Dropout(0.1))
    rnn_lstm3.add(LSTM(64))
    rnn_lstm3.add(Dense(1))
    rnn_lstm3.compile(optimizer=Adam(learning_rate=0.003), loss='mse')
    rnn_lstm3.fit(xtrainN, ytrainN, batch_size=32, epochs=500, verbose=1,shuffle=False,validation_data=(xvalN,yvalN))
    ypred_rnn_lstm=rnn_lstm3.predict(xtestN)
    Y_rnn_lstm['ypred_'+str(i)]=pd.DataFrame(ypred_rnn_lstm,index=ytestN.index)

Y_rnn_lstm
# Out:
# Epoch 1/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - loss: 0.0536 - val_loss: 0.0399
# Epoch 2/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0474 - val_loss: 0.0374
# Epoch 3/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0461 - val_loss: 0.0346
# Epoch 4/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0442 - val_loss: 0.0327
# Epoch 5/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0434 - val_loss: 0.0317
# Epoch 6/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0430 - val_loss: 0.0303
# Epoch 7/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0418 - val_loss: 0.0301
# Epoch 8/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0423 - val_loss: 0.0286
# Epoch 9/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0412 - val_loss: 0.0311
# Epoch 10/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0433 - val_loss: 0.0302
# Epoch 11/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0418 - val_loss: 0.0313
# ...

# %%
z=[]
o=[]
e=[]
for i in range(4):
    z.append(r2_score(Y_rnn_lstm.iloc[:,0], Y_rnn_lstm.iloc[:,i+1]))
    o.append(mean_absolute_error(Y_rnn_lstm.iloc[:,0], Y_rnn_lstm.iloc[:,i+1]))
    e.append(mean_squared_error(Y_rnn_lstm.iloc[:,0], Y_rnn_lstm.iloc[:,i+1]))

print(z)
print(o)
print(e)
# Out:
# [0.8390022467014576, 0.7431476311584119, 0.818768394954697, 0.8266218035604951]
# [0.06480332973089194, 0.08329349756095822, 0.07811227592206595, 0.06899919668957939]
# [0.016204228665292444, 0.025851879499294936, 0.018240741310758687, 0.01745030525657134]

# %% [markdown]
# ### 3-LSTM (Adam learning_rate=0.001)

# %%
Y_rnn_lstm_=pd.DataFrame(ytestN,index=ytestN.index).rename({'y':'ytest'},axis=1)
for i in range(4):
    rnn_lstm3_ = Sequential()
    rnn_lstm3_.add(LSTM(64, input_shape=(len(xtrainN.columns), 1),return_sequences=True))
    rnn_lstm3_.add(Dropout(0.1))
    rnn_lstm3_.add(LSTM(64,return_sequences=True))
    rnn_lstm3_.add(Dropout(0.1))
    rnn_lstm3_.add(LSTM(64))
    rnn_lstm3_.add(Dense(1))
    rnn_lstm3_.compile(optimizer='adam', loss='mse')
    rnn_lstm3_.fit(xtrainN, ytrainN, batch_size=32, epochs=500, verbose=1,shuffle=False,validation_data=(xvalN,yvalN))
    ypred_rnn_lstm_=rnn_lstm3_.predict(xtestN)
    Y_rnn_lstm_['ypred_'+str(i)]=pd.DataFrame(ypred_rnn_lstm_,index=ytestN.index)

Y_rnn_lstm_
# Out:
# Epoch 1/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - loss: 0.0500 - val_loss: 0.0382
# Epoch 2/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0465 - val_loss: 0.0339
# Epoch 3/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0435 - val_loss: 0.0333
# Epoch 4/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0431 - val_loss: 0.0320
# Epoch 5/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0421 - val_loss: 0.0309
# Epoch 6/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0414 - val_loss: 0.0297
# Epoch 7/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0410 - val_loss: 0.0292
# Epoch 8/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0409 - val_loss: 0.0283
# Epoch 9/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0405 - val_loss: 0.0283
# Epoch 10/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0403 - val_loss: 0.0278
# Epoch 11/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0397 - val_loss: 0.0276
# ...

# %%
zz=[]
oo=[]
ee=[]
for i in range(4):
    zz.append(r2_score(Y_rnn_lstm_.iloc[:,0], Y_rnn_lstm_.iloc[:,i+1]))
    oo.append(mean_absolute_error(Y_rnn_lstm_.iloc[:,0], Y_rnn_lstm_.iloc[:,i+1]))
    ee.append(mean_squared_error(Y_rnn_lstm_.iloc[:,0], Y_rnn_lstm_.iloc[:,i+1]))

print(zz)
print(oo)
print(ee)
# Out:
# [0.8241322368692914, 0.8231212431660915, 0.7414976537210751, 0.8238696925671959]
# [0.06928448431392217, 0.07494987765160611, 0.08337620086445871, 0.06788685445870123]
# [0.017700877125527516, 0.0178026324159597, 0.026017947727822323, 0.01772730189120754]

# %%
dic={'Notas':'Ventana deslizante de tamaño 4 para variables: dependiente, temperatura y trend',
    'Regresion lineal': r2_score(Y_rl.ytest, Y_rl.ypred),
    'KNN': r2_score(Y_knn.ytest, Y_knn.ypred),
    'Random Forest': r2_score(Y_rf.ytest, Y_rf.ypred),
    'Gradient Boosting': r2_score(Y_gbr.ytest, Y_gbr.ypred),
    'RNA adam learning_rate=0.005': statistics.mean(vvv),
    'RNA adam learning_rate=0.003': statistics.mean(v),
    'RNA adam learning_rate=0.001': statistics.mean(vv),
    'RNN adam learning_rate=0.005': statistics.mean(www),
    'RNN adam learning_rate=0.003': statistics.mean(w),
    'RNN adam learning_rate=0.001': statistics.mean(ww),
    'LSTM adam learning_rate=0.001': statistics.mean(uu),
    'LSTM adam learning_rate=0.003': statistics.mean(u),
    'LSTM adam learning_rate=0.005': statistics.mean(uuu),
    'GRU adam learning_rate=0.005': statistics.mean(yyy),
    'GRU adam learning_rate=0.003': statistics.mean(y),
    'GRU adam learning_rate=0.001': statistics.mean(yy),
    'RNN-LSTM adam learning_rate=0.005': statistics.mean(zzz),
    'RNN-LSTM adam learning_rate=0.003': statistics.mean(z),
    'RNN-LSTM adam learning_rate=0.001': statistics.mean(zz)}
dic
# Out:
# {'Notas': 'Ventana deslizante de tamaño 4 para variables: dependiente, temperatura y trend',
#  'Regresion lineal': 0.9056827873317348,
#  'KNN': 0.7936249726946073,
#  'Random Forest': 0.8338059684725174,
#  'Gradient Boosting': 0.8162274656549952,
#  'RNA adam learning_rate=0.005': 0.927784785002892,
#  'RNA adam learning_rate=0.003': 0.9275540572716036,
#  'RNA adam learning_rate=0.001': 0.9083993497100007,
#  'RNN adam learning_rate=0.005': 0.8831565067754217,
#  'RNN adam learning_rate=0.003': 0.8638214720515827,
#  'RNN adam learning_rate=0.001': 0.8857664782886516,
#  'LSTM adam learning_rate=0.001': 0.8747014593001607,
#  'LSTM adam learning_rate=0.003': 0.8068429470356913,
#  'LSTM adam learning_rate=0.005': 0.8502843757888899,
#  'GRU adam learning_rate=0.005': 0.8404859742993742,
#  'GRU adam learning_rate=0.003': 0.8663932493016817,
#  'GRU adam learning_rate=0.001': 0.8351163689596445,
#  'RNN-LSTM adam learning_rate=0.005': 0.8061422390242267,
# ...

# %%
dic2={'Notas':'Ventana deslizante de tamaño 4 para variables: dependiente, temperatura y trend',
    'Regresion lineal': mean_squared_error(Y_rl.ytest, Y_rl.ypred),
    'KNN': mean_squared_error(Y_knn.ytest, Y_knn.ypred),
    'Random Forest': mean_squared_error(Y_rf.ytest, Y_rf.ypred),
    'Gradient Boosting': mean_squared_error(Y_gbr.ytest, Y_gbr.ypred),
    'RNA adam learning_rate=0.005': statistics.mean(aaa),
    'RNA adam learning_rate=0.003': statistics.mean(a),
    'RNA adam learning_rate=0.001': statistics.mean(aa),
    'RNN adam learning_rate=0.005': statistics.mean(bbb),
    'RNN adam learning_rate=0.003': statistics.mean(b),
    'RNN adam learning_rate=0.001': statistics.mean(bb),
    'LSTM adam learning_rate=0.001': statistics.mean(cc),
    'LSTM adam learning_rate=0.003': statistics.mean(c),
    'LSTM adam learning_rate=0.005': statistics.mean(ccc),
    'GRU adam learning_rate=0.005': statistics.mean(ddd),
    'GRU adam learning_rate=0.003': statistics.mean(d),
    'GRU adam learning_rate=0.001': statistics.mean(dd),
    'RNN-LSTM adam learning_rate=0.005': statistics.mean(eee),
    'RNN-LSTM adam learning_rate=0.003': statistics.mean(e),
    'RNN-LSTM adam learning_rate=0.001': statistics.mean(ee)}
dic2
# Out:
# {'Notas': 'Ventana deslizante de tamaño 4 para variables: dependiente, temperatura y trend',
#  'Regresion lineal': 0.009492913098703617,
#  'KNN': 0.020771396275707114,
#  'Random Forest': 0.0167272277687277,
#  'Gradient Boosting': 0.018496482763984818,
#  'RNA adam learning_rate=0.005': 0.007268373831009171,
#  'RNA adam learning_rate=0.003': 0.0072915962974139555,
#  'RNA adam learning_rate=0.001': 0.009219494389069055,
#  'RNN adam learning_rate=0.005': 0.011760155924360704,
#  'RNN adam learning_rate=0.003': 0.013706203726254428,
#  'RNN adam learning_rate=0.001': 0.011497465456054269,
#  'LSTM adam learning_rate=0.001': 0.012611146201293166,
#  'LSTM adam learning_rate=0.003': 0.019441023184613597,
#  'LSTM adam learning_rate=0.005': 0.015068696051833579,
#  'GRU adam learning_rate=0.005': 0.01605489328153053,
#  'GRU adam learning_rate=0.003': 0.013447357464222895,
#  'GRU adam learning_rate=0.001': 0.016595337548513618,
# ...

# %%
dic3={'Notas':'Ventana deslizante de tamaño 4 para variables: dependiente, temperatura y trend',
    'Regresion lineal': mean_absolute_error(Y_rl.ytest, Y_rl.ypred),
    'KNN': mean_absolute_error(Y_knn.ytest, Y_knn.ypred),
    'Random Forest': mean_absolute_error(Y_rf.ytest, Y_rf.ypred),
    'Gradient Boosting': mean_absolute_error(Y_gbr.ytest, Y_gbr.ypred),
    'RNA adam learning_rate=0.005': statistics.mean(kkk),
    'RNA adam learning_rate=0.003': statistics.mean(k),
    'RNA adam learning_rate=0.001': statistics.mean(kk),
    'RNN adam learning_rate=0.005': statistics.mean(lll),
    'RNN adam learning_rate=0.003': statistics.mean(l),
    'RNN adam learning_rate=0.001': statistics.mean(ll),
    'LSTM adam learning_rate=0.001': statistics.mean(mm),
    'LSTM adam learning_rate=0.003': statistics.mean(m),
    'LSTM adam learning_rate=0.005': statistics.mean(mmm),
    'GRU adam learning_rate=0.005': statistics.mean(nnn),
    'GRU adam learning_rate=0.003': statistics.mean(n),
    'GRU adam learning_rate=0.001': statistics.mean(nn),
    'RNN-LSTM adam learning_rate=0.005': statistics.mean(ooo),
    'RNN-LSTM adam learning_rate=0.003': statistics.mean(o),
    'RNN-LSTM adam learning_rate=0.001': statistics.mean(oo)}
dic3
# Out:
# {'Notas': 'Ventana deslizante de tamaño 4 para variables: dependiente, temperatura y trend',
#  'Regresion lineal': 0.05228518507408453,
#  'KNN': 0.07960915602616006,
#  'Random Forest': 0.06580232014948616,
#  'Gradient Boosting': 0.06820301339764148,
#  'RNA adam learning_rate=0.005': 0.04472356001976721,
#  'RNA adam learning_rate=0.003': 0.04792955643944071,
#  'RNA adam learning_rate=0.001': 0.05217855909027664,
#  'RNN adam learning_rate=0.005': 0.055525202459115644,
#  'RNN adam learning_rate=0.003': 0.060089158004795716,
#  'RNN adam learning_rate=0.001': 0.05602537783441269,
#  'LSTM adam learning_rate=0.001': 0.06062406050980689,
#  'LSTM adam learning_rate=0.003': 0.07322240141186673,
#  'LSTM adam learning_rate=0.005': 0.06369247126169109,
#  'GRU adam learning_rate=0.005': 0.07747185122756761,
#  'GRU adam learning_rate=0.003': 0.06428872192466958,
#  'GRU adam learning_rate=0.001': 0.06813739533176484,
#  'RNN-LSTM adam learning_rate=0.005': 0.07232779198973252,
# ...

# %%
print(dic['Notas'])
DF=pd.DataFrame(dic.values(),index=dic.keys(),columns=['r2_score']).iloc[1:,:]
DF2=pd.DataFrame(dic2.values(),index=dic2.keys(),columns=['mse']).iloc[1:,:]
DF3=pd.DataFrame(dic3.values(),index=dic3.keys(),columns=['mae']).iloc[1:,:]
df=pd.concat([DF,DF2,DF3],axis=1)
df
# Out:
# Ventana deslizante de tamaño 4 para variables: dependiente, temperatura y trend
#                                    r2_score       mse       mae
# Regresion lineal                   0.905683  0.009493  0.052285
# KNN                                0.793625  0.020771  0.079609
# Random Forest                      0.833806  0.016727  0.065802
# Gradient Boosting                  0.816227  0.018496  0.068203
# RNA adam learning_rate=0.005       0.927785  0.007268  0.044724
# RNA adam learning_rate=0.003       0.927554  0.007292   0.04793
# RNA adam learning_rate=0.001       0.908399  0.009219  0.052179
# RNN adam learning_rate=0.005       0.883157   0.01176  0.055525
# RNN adam learning_rate=0.003       0.863821  0.013706  0.060089
# RNN adam learning_rate=0.001       0.885766  0.011497  0.056025
# LSTM adam learning_rate=0.001      0.874701  0.012611  0.060624
# LSTM adam learning_rate=0.003      0.806843  0.019441  0.073222
# ...

# %%
colores_r2=['#f1c40f' if i==max(df.r2_score) else '#76d7c4' for i in df.r2_score]
colores_mse=['#f1c40f' if i==min(df.mse) else '#76d7c4' for i in df.mse]
colores_mae=['#f1c40f' if i==min(df.mae) else '#76d7c4' for i in df.mae]

# %%
#Gráfica para los valores de r2
fig, ax = plt.subplots()
B=plt.barh(y=df.index,width=df.r2_score,color=colores_r2)
ax.bar_label(B, padding=3)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False);
ax.spines['bottom'].set_visible(False)
plt.title('r2_score de los modelos')
ax.tick_params(bottom=False, labelbottom=False);

# %%
#Gráfica para los valores de mase
fig, ax = plt.subplots()
B=plt.barh(y=df.index,width=df.mse,color=colores_mse)
ax.bar_label(B, padding=3)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False);
ax.spines['bottom'].set_visible(False)
plt.title('mean squared error de los modelos')
ax.tick_params(bottom=False, labelbottom=False);

# %%
#Gráfica para los valores de mae
fig, ax = plt.subplots()
B=plt.barh(y=df.index,width=df.mae, color=colores_mae)
ax.bar_label(B, padding=3)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
plt.title('mean absolute error de los modelos')
ax.tick_params(bottom=False, labelbottom=False);

# %%
print('Fin:',datetime.now())
# Out:
# Fin: 2025-05-16 18:26:31.610060
