# %%
import warnings 
warnings.filterwarnings('ignore')
from datetime import datetime, timedelta, date
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("../Datos en bruto/Malaria/ECDC_surveillance_data_Malaria.csv", sep=",")
data
# Out:
#       HealthTopic                      Population  \
# 0         Malaria                 Confirmed cases
# 1         Malaria                 Confirmed cases
# 2         Malaria                 Confirmed cases
# 3         Malaria                 Confirmed cases
# 4         Malaria                 Confirmed cases
# ...           ...                             ...
# 24999     Malaria  Confirmed cases - Data quality
# 25000     Malaria  Confirmed cases - Data quality
# 25001     Malaria  Confirmed cases - Data quality
# 25002     Malaria  Confirmed cases - Data quality
# 25003     Malaria  Confirmed cases - Data quality
#
#                                                Indicator      Unit     Time  \
# 0                                      Notification rate  N/100000  2008-01
# 1                                      Notification rate  N/100000  2008-01
# 2                                      Notification rate  N/100000  2008-01
# ...

# %%
malaria_ESP=data[(data.Indicator=='Reported cases') & (data.RegionName=='Spain')]

# %%
malaria_ESP['Time'] = pd.to_datetime(malaria_ESP['Time'])
malaria_ESP['NumValue'] = pd.to_numeric(malaria_ESP['NumValue'])

# %%
malaria_ESP=malaria_ESP.loc[:,['Time','NumValue']]
malaria_ESP.set_index('Time', inplace=True)
malaria_ESP
# Out:
#             NumValue
# Time
# 2008-01-01      17.0
# 2008-02-01      12.0
# 2008-03-01      13.0
# 2008-04-01      12.0
# 2008-05-01      16.0
# ...              ...
# 2023-08-01     109.0
# 2023-09-01     123.0
# 2023-10-01     130.0
# 2023-11-01      73.0
# 2023-12-01      40.0
#
# [192 rows x 1 columns]

# %%
plt.figure(figsize=(13,5))
sns.lineplot(data=malaria_ESP,x=malaria_ESP.index,y=malaria_ESP.NumValue)
plt.xticks(rotation=90)
plt.show()

# %%
#Exportamos los datos relativos al 
malaria_ESP.to_csv('malaria_esp_indexado.csv',index=True,encoding='utf-8')
