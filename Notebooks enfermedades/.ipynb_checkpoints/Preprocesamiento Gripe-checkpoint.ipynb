# %%
import warnings 
warnings.filterwarnings('ignore')
from datetime import datetime, timedelta, date
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Carga de los datos en bruto
data=pd.read_csv("../Datos en bruto/Gripe/VIW_FNT.csv", sep=",") 
data
# Out:
#        WHOREGION FLUSEASON HEMISPHERE          ITZ COUNTRY_CODE  \
# 0            AMR        YR         NH  FLU_CNT_AMC          ABW
# 1            AMR        YR         NH  FLU_CNT_AMC          ABW
# 2            AMR        YR         NH  FLU_CNT_AMC          ABW
# 3            AMR        YR         NH  FLU_CNT_AMC          ABW
# 4            AMR        YR         NH  FLU_CNT_AMC          ABW
# ...          ...       ...        ...          ...          ...
# 170061       AFR        YR         SH  FLU_EST_AFR          ZWE
# 170062       AFR        YR         SH  FLU_EST_AFR          ZWE
# 170063       AFR        YR         SH  FLU_EST_AFR          ZWE
# 170064       AFR        YR         SH  FLU_EST_AFR          ZWE
# 170065       AFR        YR         SH  FLU_EST_AFR          ZWE
#
#        COUNTRY_AREA_TERRITORY ISO_WEEKSTARTDATE  ISO_YEAR  ISO_WEEK  \
# 0                       Aruba        2017-01-30      2017         5
# 1                       Aruba        2017-03-06      2017        10
# 2                       Aruba        2017-01-23      2017         4
# 3                       Aruba        2017-02-27      2017         9
# 4                       Aruba        2017-01-16      2017         3
# ...                       ...               ...       ...       ...
# 170061               Zimbabwe        2024-10-14      2024        42
# 170062               Zimbabwe        2024-11-18      2024        47
# 170063               Zimbabwe        2024-12-23      2024        52
# 170064               Zimbabwe        2025-01-27      2025         5
# 170065               Zimbabwe        2025-03-03      2025        10
#
#        MMWR_WEEKSTARTDATE  ...  OTHERRESPVIRUS  OTHER_RESPVIRUS_DETAILS  \
# 0              2017-01-29  ...             NaN                      NaN
# 1              2017-03-05  ...             NaN                      NaN
# 2              2017-01-22  ...             NaN                      NaN
# 3              2017-02-26  ...             NaN                      NaN
# 4              2017-01-15  ...             NaN                      NaN
# ...                   ...  ...             ...                      ...
# 170061         2024-10-13  ...             NaN                      NaN
# 170062         2024-11-17  ...             NaN                      NaN
# 170063         2024-12-22  ...             NaN                      NaN
# 170064         2025-01-26  ...             NaN                      NaN
# 170065         2025-03-02  ...             NaN                      NaN
#
#        LAB_RESULT_COMMENT  WCR_COMMENT  ISO2   ISOYW  MMWRYW  \
# 0                     NaN          NaN    AW  201705  201705
# 1                     NaN          NaN    AW  201710  201710
# 2                     NaN          NaN    AW  201704  201704
# 3                     NaN          NaN    AW  201709  201709
# 4                     NaN          NaN    AW  201703  201703
# ...                   ...          ...   ...     ...     ...
# 170061                NaN          NaN    ZW  202442  202442
# 170062                NaN          NaN    ZW  202447  202447
# 170063                NaN          NaN    ZW  202452  202452
# 170064                NaN          NaN    ZW  202505  202505
# 170065                NaN          NaN    ZW  202510  202510
#
#         PSOURCE_SUBTYPE_INF  PSOURCE_PPOS_INF  PSOURCE_RSV
# 0                       NaN               NaN          NaN
# 1                       NaN               NaN          NaN
# 2                       NaN               NaN          NaN
# 3                       NaN               NaN          NaN
# 4                       NaN               NaN          NaN
# ...                     ...               ...          ...
# 170061                  NaN               NaN          NaN
# 170062                  NaN               NaN          NaN
# 170063                  NaN               NaN          NaN
# 170064                  NaN               NaN          NaN
# 170065                  NaN               NaN          NaN
#
# [170066 rows x 53 columns]

# %%
# Filtrado de los registros del 2008 y años posteriores para la región de España siendo la fuente de origen de estos de 
# tipo SENTINEL
flu_ESP=data[(data.COUNTRY_AREA_TERRITORY=='Spain')&(data.ORIGIN_SOURCE=='SENTINEL')]
flu_ESP
# Out:
#       WHOREGION FLUSEASON HEMISPHERE         ITZ COUNTRY_CODE  \
# 30526       EUR        NH         NH  FLU_SW_EUR          ESP
# 30528       EUR        NH         NH  FLU_SW_EUR          ESP
# 30780       EUR        NH         NH  FLU_SW_EUR          ESP
# 30781       EUR        NH         NH  FLU_SW_EUR          ESP
# 30811       EUR        NH         NH  FLU_SW_EUR          ESP
# ...         ...       ...        ...         ...          ...
# 67505       EUR        NH         NH  FLU_SW_EUR          ESP
# 67507       EUR        NH         NH  FLU_SW_EUR          ESP
# 67511       EUR        NH         NH  FLU_SW_EUR          ESP
# 67515       EUR        NH         NH  FLU_SW_EUR          ESP
# 67518       EUR        NH         NH  FLU_SW_EUR          ESP
#
#       COUNTRY_AREA_TERRITORY ISO_WEEKSTARTDATE  ISO_YEAR  ISO_WEEK  \
# 30526                  Spain        2013-10-21      2013        43
# 30528                  Spain        2013-11-25      2013        48
# 30780                  Spain        2017-01-16      2017         3
# 30781                  Spain        2017-02-20      2017         8
# 30811                  Spain        2017-03-27      2017        13
# ...                      ...               ...       ...       ...
# 67505                  Spain        2023-11-06      2023        45
# 67507                  Spain        2023-12-11      2023        50
# 67511                  Spain        2025-01-06      2025         2
# 67515                  Spain        2025-02-10      2025         7
# 67518                  Spain        2025-03-17      2025        12
#
#       MMWR_WEEKSTARTDATE  ...  OTHERRESPVIRUS  OTHER_RESPVIRUS_DETAILS  \
# 30526         2013-10-20  ...             NaN                      NaN
# 30528         2013-11-24  ...             NaN                      NaN
# 30780         2017-01-15  ...             NaN                      NaN
# 30781         2017-02-19  ...             NaN                      NaN
# 30811         2017-03-26  ...             NaN                      NaN
# ...                  ...  ...             ...                      ...
# 67505         2023-11-05  ...             NaN                      NaN
# 67507         2023-12-10  ...             NaN                      NaN
# 67511         2025-01-05  ...             NaN                      NaN
# 67515         2025-02-09  ...             NaN                      NaN
# 67518         2025-03-16  ...             NaN                      NaN
#
#       LAB_RESULT_COMMENT  WCR_COMMENT  ISO2   ISOYW  MMWRYW  \
# 30526                NaN          NaN    ES  201343  201343
# 30528                NaN          NaN    ES  201348  201348
# 30780                NaN          NaN    ES  201703  201703
# 30781                NaN          NaN    ES  201708  201708
# 30811                NaN          NaN    ES  201713  201713
# ...                  ...          ...   ...     ...     ...
# 67505                NaN          NaN    ES  202345  202345
# 67507                NaN          NaN    ES  202350  202350
# 67511                NaN          NaN    ES  202502  202502
# 67515                NaN          NaN    ES  202507  202507
# 67518                NaN          NaN    ES  202512  202512
#
#        PSOURCE_SUBTYPE_INF  PSOURCE_PPOS_INF  PSOURCE_RSV
# 30526                  1.0               1.0          1.0
# 30528                  1.0               1.0          1.0
# 30780                  1.0               1.0          1.0
# 30781                  1.0               1.0          1.0
# 30811                  1.0               1.0          1.0
# ...                    ...               ...          ...
# 67505                  1.0               1.0          1.0
# 67507                  1.0               1.0          1.0
# 67511                  1.0               1.0          1.0
# 67515                  1.0               1.0          1.0
# 67518                  1.0               1.0          1.0
#
# [524 rows x 53 columns]

# %%
#Se modifica el valor de la fecha para que sean valores en domingos en vez de lunes
flu_ESP['Fecha']=pd.to_datetime(flu_ESP['ISO_WEEKSTARTDATE'])-timedelta(days=1)
flu_ESP
# Out:
#       WHOREGION FLUSEASON HEMISPHERE         ITZ COUNTRY_CODE  \
# 30526       EUR        NH         NH  FLU_SW_EUR          ESP
# 30528       EUR        NH         NH  FLU_SW_EUR          ESP
# 30780       EUR        NH         NH  FLU_SW_EUR          ESP
# 30781       EUR        NH         NH  FLU_SW_EUR          ESP
# 30811       EUR        NH         NH  FLU_SW_EUR          ESP
# ...         ...       ...        ...         ...          ...
# 67505       EUR        NH         NH  FLU_SW_EUR          ESP
# 67507       EUR        NH         NH  FLU_SW_EUR          ESP
# 67511       EUR        NH         NH  FLU_SW_EUR          ESP
# 67515       EUR        NH         NH  FLU_SW_EUR          ESP
# 67518       EUR        NH         NH  FLU_SW_EUR          ESP
#
#       COUNTRY_AREA_TERRITORY ISO_WEEKSTARTDATE  ISO_YEAR  ISO_WEEK  \
# 30526                  Spain        2013-10-21      2013        43
# 30528                  Spain        2013-11-25      2013        48
# 30780                  Spain        2017-01-16      2017         3
# 30781                  Spain        2017-02-20      2017         8
# 30811                  Spain        2017-03-27      2017        13
# ...                      ...               ...       ...       ...
# 67505                  Spain        2023-11-06      2023        45
# 67507                  Spain        2023-12-11      2023        50
# 67511                  Spain        2025-01-06      2025         2
# 67515                  Spain        2025-02-10      2025         7
# 67518                  Spain        2025-03-17      2025        12
#
#       MMWR_WEEKSTARTDATE  ...  OTHER_RESPVIRUS_DETAILS  LAB_RESULT_COMMENT  \
# 30526         2013-10-20  ...                      NaN                 NaN
# 30528         2013-11-24  ...                      NaN                 NaN
# 30780         2017-01-15  ...                      NaN                 NaN
# 30781         2017-02-19  ...                      NaN                 NaN
# 30811         2017-03-26  ...                      NaN                 NaN
# ...                  ...  ...                      ...                 ...
# 67505         2023-11-05  ...                      NaN                 NaN
# 67507         2023-12-10  ...                      NaN                 NaN
# 67511         2025-01-05  ...                      NaN                 NaN
# 67515         2025-02-09  ...                      NaN                 NaN
# 67518         2025-03-16  ...                      NaN                 NaN
#
#       WCR_COMMENT  ISO2   ISOYW  MMWRYW  PSOURCE_SUBTYPE_INF  \
# 30526         NaN    ES  201343  201343                  1.0
# 30528         NaN    ES  201348  201348                  1.0
# 30780         NaN    ES  201703  201703                  1.0
# 30781         NaN    ES  201708  201708                  1.0
# 30811         NaN    ES  201713  201713                  1.0
# ...           ...   ...     ...     ...                  ...
# 67505         NaN    ES  202345  202345                  1.0
# 67507         NaN    ES  202350  202350                  1.0
# 67511         NaN    ES  202502  202502                  1.0
# 67515         NaN    ES  202507  202507                  1.0
# 67518         NaN    ES  202512  202512                  1.0
#
#        PSOURCE_PPOS_INF  PSOURCE_RSV      Fecha
# 30526               1.0          1.0 2013-10-20
# 30528               1.0          1.0 2013-11-24
# 30780               1.0          1.0 2017-01-15
# 30781               1.0          1.0 2017-02-19
# 30811               1.0          1.0 2017-03-26
# ...                 ...          ...        ...
# 67505               1.0          1.0 2023-11-05
# 67507               1.0          1.0 2023-12-10
# 67511               1.0          1.0 2025-01-05
# 67515               1.0          1.0 2025-02-09
# 67518               1.0          1.0 2025-03-16
#
# [524 rows x 54 columns]

# %%
# Para el tratamiento de los valores nulos se rellenan los nulos de las variantes de tipo A y B con ceros para posteriormente
# rellenar los nulos de todas las variantes con la suma de ambas.
flu_ESP.INF_A=flu_ESP.INF_A.fillna(0)
flu_ESP.INF_B=flu_ESP.INF_B.fillna(0)
flu_ESP.INF_ALL=flu_ESP.INF_ALL.fillna(flu_ESP.INF_A+flu_ESP.INF_B)
flu_ESP
# Out:
#       WHOREGION FLUSEASON HEMISPHERE         ITZ COUNTRY_CODE  \
# 30526       EUR        NH         NH  FLU_SW_EUR          ESP
# 30528       EUR        NH         NH  FLU_SW_EUR          ESP
# 30780       EUR        NH         NH  FLU_SW_EUR          ESP
# 30781       EUR        NH         NH  FLU_SW_EUR          ESP
# 30811       EUR        NH         NH  FLU_SW_EUR          ESP
# ...         ...       ...        ...         ...          ...
# 67505       EUR        NH         NH  FLU_SW_EUR          ESP
# 67507       EUR        NH         NH  FLU_SW_EUR          ESP
# 67511       EUR        NH         NH  FLU_SW_EUR          ESP
# 67515       EUR        NH         NH  FLU_SW_EUR          ESP
# 67518       EUR        NH         NH  FLU_SW_EUR          ESP
#
#       COUNTRY_AREA_TERRITORY ISO_WEEKSTARTDATE  ISO_YEAR  ISO_WEEK  \
# 30526                  Spain        2013-10-21      2013        43
# 30528                  Spain        2013-11-25      2013        48
# 30780                  Spain        2017-01-16      2017         3
# 30781                  Spain        2017-02-20      2017         8
# 30811                  Spain        2017-03-27      2017        13
# ...                      ...               ...       ...       ...
# 67505                  Spain        2023-11-06      2023        45
# 67507                  Spain        2023-12-11      2023        50
# 67511                  Spain        2025-01-06      2025         2
# 67515                  Spain        2025-02-10      2025         7
# 67518                  Spain        2025-03-17      2025        12
#
#       MMWR_WEEKSTARTDATE  ...  OTHER_RESPVIRUS_DETAILS  LAB_RESULT_COMMENT  \
# 30526         2013-10-20  ...                      NaN                 NaN
# 30528         2013-11-24  ...                      NaN                 NaN
# 30780         2017-01-15  ...                      NaN                 NaN
# 30781         2017-02-19  ...                      NaN                 NaN
# 30811         2017-03-26  ...                      NaN                 NaN
# ...                  ...  ...                      ...                 ...
# 67505         2023-11-05  ...                      NaN                 NaN
# 67507         2023-12-10  ...                      NaN                 NaN
# 67511         2025-01-05  ...                      NaN                 NaN
# 67515         2025-02-09  ...                      NaN                 NaN
# 67518         2025-03-16  ...                      NaN                 NaN
#
#       WCR_COMMENT  ISO2   ISOYW  MMWRYW  PSOURCE_SUBTYPE_INF  \
# 30526         NaN    ES  201343  201343                  1.0
# 30528         NaN    ES  201348  201348                  1.0
# 30780         NaN    ES  201703  201703                  1.0
# 30781         NaN    ES  201708  201708                  1.0
# 30811         NaN    ES  201713  201713                  1.0
# ...           ...   ...     ...     ...                  ...
# 67505         NaN    ES  202345  202345                  1.0
# 67507         NaN    ES  202350  202350                  1.0
# 67511         NaN    ES  202502  202502                  1.0
# 67515         NaN    ES  202507  202507                  1.0
# 67518         NaN    ES  202512  202512                  1.0
#
#        PSOURCE_PPOS_INF  PSOURCE_RSV      Fecha
# 30526               1.0          1.0 2013-10-20
# 30528               1.0          1.0 2013-11-24
# 30780               1.0          1.0 2017-01-15
# 30781               1.0          1.0 2017-02-19
# 30811               1.0          1.0 2017-03-26
# ...                 ...          ...        ...
# 67505               1.0          1.0 2023-11-05
# 67507               1.0          1.0 2023-12-10
# 67511               1.0          1.0 2025-01-05
# 67515               1.0          1.0 2025-02-09
# 67518               1.0          1.0 2025-03-16
#
# [524 rows x 54 columns]

# %%
#Finalmente, nos quedamos con las variables INF_ALL y Fecha
flu_ESP=flu_ESP.loc[:,['INF_ALL','Fecha']]
flu_ESP.set_index('Fecha',inplace=True)
flu_ESP=flu_ESP.sort_index()
flu_ESP
# Out:
#             INF_ALL
# Fecha
# 2013-09-29      1.0
# 2013-10-06      1.0
# 2013-10-13      0.0
# 2013-10-20      1.0
# 2013-10-27      0.0
# ...             ...
# 2025-02-23    166.0
# 2025-03-02     76.0
# 2025-03-09    117.0
# 2025-03-16     65.0
# 2025-03-23     54.0
#
# [524 rows x 1 columns]

# %%
plt.figure(figsize=(13,5))
sns.lineplot(data=flu_ESP,x=flu_ESP.index,y=flu_ESP.INF_ALL)
plt.xticks(rotation=90)
plt.show()

# %%
#Exportamos los datos relativos a la gripe en España
flu_ESP.to_csv('flu_esp_indexado.csv',index=True,encoding='utf-8')
