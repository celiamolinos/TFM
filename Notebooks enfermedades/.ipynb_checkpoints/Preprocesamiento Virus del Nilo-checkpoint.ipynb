# %%
import warnings 
warnings.filterwarnings('ignore')
from datetime import datetime, timedelta, date
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Carga de los datos en bruto
data=pd.read_csv("../Datos en bruto/Virus del Nilo/ECDC_surveillance_data_West_Nile_virus_infection.csv", sep=",")
data
# Out:
#                     HealthTopic Population       Indicator Unit     Time  \
# 0     West Nile virus infection  All cases  Reported cases    N  2008-01
# 1     West Nile virus infection  All cases  Reported cases    N  2008-01
# 2     West Nile virus infection  All cases  Reported cases    N  2008-01
# 3     West Nile virus infection  All cases  Reported cases    N  2008-01
# 4     West Nile virus infection  All cases  Reported cases    N  2008-01
# ...                         ...        ...             ...  ...      ...
# 6669  West Nile virus infection  All cases  Reported cases    N  2023-12
# 6670  West Nile virus infection  All cases  Reported cases    N  2023-12
# 6671  West Nile virus infection  All cases  Reported cases    N  2023-12
# 6672  West Nile virus infection  All cases  Reported cases    N  2023-12
# 6673  West Nile virus infection  All cases  Reported cases    N  2023-12
#
#      RegionCode RegionName     NumValue  TxtValue
# ...

# %%
nilo_IT=data[(data.Indicator=='Reported cases') & (data.RegionName=='Italy')]
nilo_IT
# Out:
#                     HealthTopic Population       Indicator Unit     Time  \
# 16    West Nile virus infection  All cases  Reported cases    N  2008-01
# 45    West Nile virus infection  All cases  Reported cases    N  2008-02
# 74    West Nile virus infection  All cases  Reported cases    N  2008-03
# 103   West Nile virus infection  All cases  Reported cases    N  2008-04
# 132   West Nile virus infection  All cases  Reported cases    N  2008-05
# ...                         ...        ...             ...  ...      ...
# 6500  West Nile virus infection  All cases  Reported cases    N  2023-08
# 6539  West Nile virus infection  All cases  Reported cases    N  2023-09
# 6578  West Nile virus infection  All cases  Reported cases    N  2023-10
# 6617  West Nile virus infection  All cases  Reported cases    N  2023-11
# 6656  West Nile virus infection  All cases  Reported cases    N  2023-12
#
#      RegionCode RegionName       NumValue  TxtValue
# ...

# %%
nilo_IT['Time'] = pd.to_datetime(nilo_IT['Time'])
nilo_IT['NumValue'] = pd.to_numeric(nilo_IT['NumValue'])

# %%
nilo_IT=nilo_IT.loc[:,['NumValue','Time']]
nilo_IT.set_index('Time', inplace=True)
nilo_IT
# Out:
#             NumValue
# Time
# 2008-01-01       0.0
# 2008-02-01       0.0
# 2008-03-01       0.0
# 2008-04-01       0.0
# 2008-05-01       0.0
# ...              ...
# 2023-08-01     183.0
# 2023-09-01      75.0
# 2023-10-01      18.0
# 2023-11-01       4.0
# 2023-12-01       0.0
#
# [192 rows x 1 columns]

# %%
plt.figure(figsize=(13,5))
sns.lineplot(data=nilo_IT,x=nilo_IT.index,y=nilo_IT.NumValue)
plt.xticks(rotation=90)
plt.show()

# %%
#Exportamos los datos relativos al virus del Nilo en Italia
nilo_IT.to_csv('nilo_it_indexado.csv',index=True,encoding='utf-8')
